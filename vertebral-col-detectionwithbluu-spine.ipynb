# %%
import os

data_folder = '/kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400'

for root, dirs, files in os.walk(data_folder):
    level = root.replace(data_folder, '').count(os.sep)
    indent = ' ' * 4 * (level)
    print('{}{}/'.format(indent, os.path.basename(root)))
    subindent = ' ' * 4 * (level + 1)
    for f in files:
        print('{}{}'.format(subindent, f))
# Out:
# BUU-LSPINE_400/
#     metadata.csv
#     yolov8_config.yaml
#     BUU-LSPINE_400_report.xlsx
#     AP/
#         0363-F-062Y0.jpg
#         0293-M-068Y0.csv
#         0256-M-056Y0.csv
#         0333-F-070Y0.jpg
#         0022-M-006Y0.csv
#         0090-F-016Y0.csv
#         0460-F-019Y0.csv
#         0070-F-027Y0.jpg
#         0328-M-083Y0.jpg
#         0107-F-033Y0.jpg
#         0324-F-061Y0.csv
#         0429-M-083Y0.csv
#         0416-F-022Y0.jpg
#         0198-F-063Y0.csv
#         0480-M-052Y0.jpg
#         0273-M-056Y0.csv
#         0105-F-009Y0.jpg
#         0245-F-086Y0.csv
#         0148-M-058Y0.csv
#         0158-F-072Y0.csv
#         0458-M-020Y0.csv
#         0040-M-023Y0.jpg
#         0325-M-039Y0.csv
#         0319-F-040Y0.jpg
#         0327-F-079Y0.csv
#         0412-F-023Y0.jpg
#         0379-M-040Y0.jpg
#         0385-F-071Y0.csv
#         0258-F-058Y0.csv
#         0151-M-079Y0.jpg
#         0391-M-046Y0.csv
#         0101-F-022Y0.jpg
#         0418-F-025Y0.jpg
#         0061-F-021Y0.csv
#         0377-F-045Y0.csv
#         0423-M-065Y0.csv
#         0038-F-020Y0.jpg
#         0297-F-031Y0.csv
#         0251-M-055Y0.jpg
#         0098-F-065Y0.csv
#         0435-M-045Y0.csv
#         0229-F-078Y0.jpg
#         0314-M-015Y0.csv
#         0409-F-043Y0.csv
#         0223-F-063Y0.jpg
#         0428-F-077Y0.csv
#         0288-M-077Y0.jpg
#         0381-F-062Y0.csv
#         0321-F-069Y0.jpg
#         0009-F-038Y0.csv
#         0007-F-006Y0.jpg
#         0007-F-006Y0.csv
#         0165-M-078Y0.csv
#         0247-F-063Y0.csv
#         0275-M-074Y0.csv
#         0177-F-037Y0.jpg
#         0034-F-067Y0.jpg
#         0019-F-015Y0.csv
#         0238-F-067Y0.csv
#         0318-F-053Y0.jpg
#         0201-F-077Y0.jpg
#         0114-F-038Y0.jpg
#         0452-M-042Y0.csv
#         0016-F-023Y0.csv
#         0058-F-008Y0.jpg
#         0053-F-040Y0.csv
#         0263-F-049Y0.csv
#         0195-F-064Y0.jpg
#         0104-F-013Y0.jpg
#         0295-F-074Y0.jpg
#         0058-F-008Y0.csv
#         0241-F-078Y0.csv
#         0443-M-020Y0.csv
#         0268-M-052Y0.jpg
#         0240-F-061Y0.csv
#         0498-M-054Y0.csv
#         0064-F-017Y0.jpg
#         0326-F-026Y0.csv
#         0316-F-074Y0.csv
#         0043-F-039Y0.csv
#         0462-M-041Y0.jpg
#         0239-F-073Y0.jpg
#         0182-F-059Y0.csv
#         0489-F-052Y0.csv
#         0106-F-016Y0.csv
#         0199-F-035Y0.csv
#         0041-F-019Y0.jpg
#         0246-M-027Y0.csv
#         0332-M-084Y0.csv
#         0077-F-018Y0.csv
#         0001-F-037Y0.csv
#         0274-M-064Y0.csv
#         0260-F-084Y0.jpg
#         0336-M-050Y0.jpg
#         0345-M-064Y0.csv
#         0068-F-017Y0.csv
#         0236-M-065Y0.csv
#         0047-F-023Y0.jpg
#         0264-F-044Y0.csv
#         0042-F-019Y0.jpg
#         0050-F-015Y0.jpg
#         0036-F-016Y0.jpg
#         0170-M-074Y0.csv
#         0399-M-023Y0.jpg
#         0292-F-058Y0.jpg
#         0186-F-042Y0.jpg
#         0049-F-013Y0.jpg
#         0004-F-010Y0.csv
#         0028-F-041Y0.csv
#         0412-F-023Y0.csv
#         0497-M-027Y0.jpg
#         0169-F-044Y0.csv
#         0437-F-065Y0.csv
#         0461-F-019Y0.jpg
#         0046-F-021Y0.csv
#         0044-F-022Y0.jpg
#         0486-M-033Y0.csv
#         0344-F-058Y0.csv
#         0004-F-010Y0.jpg
#         0229-F-078Y0.csv
#         0184-M-034Y0.csv
#         0286-F-065Y0.jpg
#         0415-F-061Y0.jpg
#         0472-F-070Y0.jpg
#         0081-M-022Y0.csv
#         0295-F-074Y0.csv
#         0089-F-012Y0.csv
#         0500-M-033Y0.jpg
#         0482-F-065Y0.csv
#         0413-M-036Y0.csv
#         0498-M-054Y0.jpg
#         0134-M-038Y0.jpg
#         0149-M-062Y0.csv
#         0150-F-081Y0.csv
#         0044-F-022Y0.csv
#         0214-F-072Y0.jpg
#         0421-F-083Y0.jpg
#         0425-M-062Y0.csv
#         0315-F-067Y0.jpg
#         0395-M-080Y0.csv
#         0026-F-029Y0.jpg
#         0305-F-025Y0.jpg
#         0428-F-077Y0.jpg
#         0442-F-021Y0.jpg
#         0052-F-026Y0.jpg
#         0459-F-042Y0.csv
#         0321-F-069Y0.csv
#         0018-F-020Y0.csv
#         0324-F-061Y0.jpg
#         0323-M-054Y0.jpg
#         0172-F-078Y0.csv
#         0005-F-025Y0.jpg
#         0298-M-011Y0.csv
#         0419-F-022Y0.jpg
#         0340-M-056Y0.jpg
#         0378-F-075Y0.csv
#         0249-F-074Y0.csv
#         0183-F-080Y0.jpg
#         0061-F-021Y0.jpg
#         0459-F-042Y0.jpg
#         0019-F-015Y0.jpg
#         0112-F-064Y0.csv
#         0380-M-060Y0.jpg
#         0457-F-055Y0.jpg
#         0458-M-020Y0.jpg
#         0077-F-018Y0.jpg
#         0151-M-079Y0.csv
#         0163-F-053Y0.jpg
#         0494-F-066Y0.csv
#         0469-F-068Y0.csv
#         0218-M-067Y0.csv
#         0175-M-053Y0.csv
#         0262-F-084Y0.jpg
#         0048-F-020Y0.jpg
#         0401-M-049Y0.csv
#         0070-F-027Y0.csv
#         0230-F-078Y0.jpg
#         0487-F-047Y0.csv
#         0310-F-072Y0.jpg
#         0100-M-051Y0.jpg
#         0219-F-077Y0.jpg
#         0072-F-035Y0.jpg
#         0303-M-044Y0.csv
#         0114-F-038Y0.csv
#         0475-M-053Y0.csv
#         0175-M-053Y0.jpg
#         0400-F-024Y0.csv
#         0290-F-030Y0.csv
#         0146-M-057Y0.csv
#         0230-F-078Y0.csv
#         0059-F-028Y0.csv
#         0377-F-045Y0.jpg
#         0168-M-055Y0.jpg
#         0066-F-019Y0.jpg
#         0472-F-070Y0.csv
#         0167-F-049Y0.jpg
#         0299-F-060Y0.jpg
#         0066-F-019Y0.csv
#         0499-F-065Y0.csv
#         0032-F-007Y0.jpg
#         0313-M-036Y0.jpg
#         0265-F-081Y0.jpg
#         0493-F-029Y0.csv
#         0441-M-044Y0.jpg
#         0322-F-061Y0.jpg
#         0419-F-022Y0.csv
#         0335-F-079Y0.jpg
#         0148-M-058Y0.jpg
#         0185-F-073Y0.csv
#         0287-M-078Y0.jpg
#         0491-F-018Y0.jpg
#         0204-F-084Y0.csv
#         0035-M-026Y0.csv
#         0222-F-051Y0.jpg
#         0290-F-030Y0.jpg
#         0429-M-083Y0.jpg
#         0029-M-019Y0.jpg
#         0140-M-024Y0.jpg
#         0405-F-060Y0.csv
#         0149-M-062Y0.jpg
#         0304-M-068Y0.jpg
#         0298-M-011Y0.jpg
#         0482-F-065Y0.jpg
#         0274-M-064Y0.jpg
#         0327-F-079Y0.jpg
#         0382-M-028Y0.jpg
#         0068-F-017Y0.jpg
#         0431-F-066Y0.jpg
#         0500-M-033Y0.csv
#         0483-F-018Y0.csv
#         0299-F-060Y0.csv
#         0207-F-061Y0.jpg
#         0213-F-086Y0.jpg
#         0221-F-066Y0.csv
#         0468-F-073Y0.jpg
#         0111-F-033Y0.csv
#         0396-F-053Y0.csv
#         0449-F-059Y0.jpg
#         0426-F-063Y0.csv
#         0225-M-086Y0.csv
#         0249-F-074Y0.jpg
#         0330-M-049Y0.jpg
#         0102-F-013Y0.jpg
#         0013-M-022Y0.jpg
#         0065-F-032Y0.csv
#         0463-F-020Y0.jpg
#         0445-F-021Y0.jpg
#         0468-F-073Y0.csv
#         0411-F-066Y0.jpg
#         0246-M-027Y0.jpg
#         0152-F-026Y0.csv
#         0406-F-067Y0.csv
#         0141-M-055Y0.jpg
#         0250-F-069Y0.csv
#         0223-F-063Y0.csv
#         0171-M-058Y0.jpg
#         0465-F-040Y0.jpg
#         0012-F-013Y0.csv
#         0161-F-054Y0.jpg
#         0445-F-021Y0.csv
#         0206-F-070Y0.jpg
#         0053-F-040Y0.jpg
#         0244-M-025Y0.csv
#         0292-F-058Y0.csv
#         0199-F-035Y0.jpg
#         0302-F-068Y0.jpg
#         0490-F-038Y0.csv
#         0465-F-040Y0.csv
#         0247-F-063Y0.jpg
#         0501-M-080Y0.csv
#         0291-M-073Y0.jpg
#         0201-F-077Y0.csv
#         0427-F-050Y0.csv
#         0194-F-077Y0.csv
#         0205-M-063Y0.csv
#         0314-M-015Y0.jpg
#         0259-F-073Y0.jpg
#         0041-F-019Y0.csv
#         0399-M-023Y0.csv
#         0436-F-054Y0.csv
#         0147-F-086Y0.csv
#         0107-F-033Y0.csv
#         0063-F-036Y0.csv
#         0073-F-036Y0.jpg
#         0031-F-014Y0.jpg
#         0338-F-027Y0.jpg
#         0189-M-068Y0.jpg
#         0018-F-020Y0.jpg
#         0079-F-012Y0.jpg
#         0005-F-025Y0.csv
#         0009-F-038Y0.jpg
#         0014-F-062Y0.jpg
#         0228-F-057Y0.jpg
#         0318-F-053Y0.csv
#         0437-F-065Y0.jpg
#         0047-F-023Y0.csv
#         0118-F-015Y0.jpg
#         0121-F-072Y0.jpg
#         0384-F-078Y0.csv
#         0320-M-069Y0.jpg
#         0288-M-077Y0.csv
#         0469-F-068Y0.jpg
#         0447-M-067Y0.jpg
#         0334-F-058Y0.jpg
#         0138-M-064Y0.jpg
#         0378-F-075Y0.jpg
#         0028-F-041Y0.jpg
#         0402-F-042Y0.jpg
#         0467-F-025Y0.csv
#         0490-F-038Y0.jpg
#         0010-F-037Y0.jpg
#         0343-M-031Y0.csv
#         0112-F-064Y0.jpg
#         0252-M-056Y0.jpg
#         0432-F-054Y0.csv
#         0279-M-043Y0.jpg
#         0187-F-067Y0.csv
#         0417-F-069Y0.csv
#         0291-M-073Y0.csv
#         0248-F-058Y0.csv
#         0363-F-062Y0.csv
#         0286-F-065Y0.csv
#         0438-F-062Y0.csv
#         0263-F-049Y0.jpg
#         0281-M-052Y0.csv
#         0403-M-039Y0.jpg
#         0173-F-079Y0.jpg
#         0453-F-064Y0.jpg
#         0310-F-072Y0.csv
#         0233-F-064Y0.jpg
#         0032-F-007Y0.csv
#         0209-M-072Y0.csv
#         0306-M-072Y0.jpg
#         0284-F-061Y0.csv
#         0344-F-058Y0.jpg
#         0157-M-060Y0.jpg
#         0446-M-060Y0.jpg
#         0150-F-081Y0.jpg
#         0191-F-066Y0.jpg
#         0272-M-035Y0.jpg
#         0006-F-031Y0.jpg
#         0118-F-015Y0.csv
#         0256-M-056Y0.jpg
#         0332-M-084Y0.jpg
#         0320-M-069Y0.csv
#         0454-F-040Y0.csv
#         0440-F-030Y0.csv
#         0060-F-013Y0.csv
#         0146-M-057Y0.jpg
#         0015-M-020Y0.jpg
#         0420-F-079Y0.jpg
#         0136-F-027Y0.csv
#         0253-F-055Y0.csv
#         0411-F-066Y0.csv
#         0279-M-043Y0.csv
#         0072-F-035Y0.csv
#         0439-M-044Y0.jpg
#         0381-F-062Y0.jpg
#         0109-F-042Y0.csv
#         0329-M-051Y0.jpg
#         0188-F-066Y0.csv
#         0208-F-058Y0.csv
#         0152-F-026Y0.jpg
#         0003-F-013Y0.csv
#         0203-M-081Y0.jpg
#         0185-F-073Y0.jpg
#         0421-F-083Y0.csv
#         0434-M-041Y0.csv
#         0211-F-055Y0.jpg
#         0139-F-077Y0.csv
#         0020-M-030Y0.jpg
#         0206-F-070Y0.csv
#         0033-F-023Y0.csv
#         0167-F-049Y0.csv
#         0480-M-052Y0.csv
#         0493-F-029Y0.jpg
#         0485-M-062Y0.jpg
#         0489-F-052Y0.jpg
#         0037-F-019Y0.jpg
#         0329-M-051Y0.csv
#         0461-F-019Y0.csv
#         0189-M-068Y0.csv
#         0387-M-046Y0.jpg
#         0238-F-067Y0.jpg
#         0113-F-082Y0.csv
#         0259-F-073Y0.csv
#         0294-F-068Y0.jpg
#         0495-M-048Y0.jpg
#         0416-F-022Y0.csv
#         0014-F-062Y0.csv
#         0328-M-083Y0.csv
#         0307-F-072Y0.csv
#         0208-F-058Y0.jpg
#         0055-F-032Y0.csv
#         0494-F-066Y0.jpg
#         0166-F-071Y0.csv
#         0064-F-017Y0.csv
#         0043-F-039Y0.jpg
#         0326-F-026Y0.jpg
#         0396-F-053Y0.jpg
#         0312-M-036Y0.csv
#         0071-F-016Y0.jpg
#         0141-M-055Y0.csv
#         0144-F-038Y0.jpg
#         0452-M-042Y0.jpg
#         0164-F-064Y0.jpg
#         0402-F-042Y0.csv
#         0012-F-013Y0.jpg
#         0273-M-056Y0.jpg
#         0244-M-025Y0.jpg
#         0308-M-067Y0.csv
#         0102-F-013Y0.csv
#         0463-F-020Y0.csv
#         0499-F-065Y0.jpg
#         0078-F-016Y0.csv
#         0021-F-079Y0.jpg
#         0476-M-047Y0.csv
#         0212-F-049Y0.jpg
#         0113-F-082Y0.jpg
#         0106-F-016Y0.jpg
#         0269-M-062Y0.csv
#         0006-F-031Y0.csv
#         0057-F-030Y0.csv
#         0234-F-073Y0.csv
#         0200-M-065Y0.jpg
#         0211-F-055Y0.csv
#         0024-F-014Y0.jpg
#         0304-M-068Y0.csv
#         0067-F-028Y0.jpg
#         0285-F-061Y0.jpg
#         0386-M-071Y0.jpg
#         0231-F-056Y0.csv
#         0462-M-041Y0.csv
#         0267-F-065Y0.csv
#         0095-F-020Y0.jpg
#         0415-F-061Y0.csv
#         0142-F-051Y0.csv
#         0444-F-020Y0.csv
#         0260-F-084Y0.csv
#         0297-F-031Y0.jpg
#         0023-F-014Y0.csv
#         0171-M-058Y0.csv
#         0089-F-012Y0.jpg
#         0239-F-073Y0.csv
#         0196-F-051Y0.csv
#         0136-F-027Y0.jpg
#         0051-F-066Y0.csv
#         0306-M-072Y0.csv
#         0443-M-020Y0.jpg
#         0218-M-067Y0.jpg
#         0166-F-071Y0.jpg
#         0492-F-051Y0.csv
#         0255-F-053Y0.csv
#         0210-F-079Y0.csv
#         0457-F-055Y0.csv
#         0431-F-066Y0.csv
#         0194-F-077Y0.jpg
#         0198-F-063Y0.jpg
#         0062-F-041Y0.csv
#         0300-M-083Y0.jpg
#         0379-M-040Y0.csv
#         0323-M-054Y0.csv
#         0340-M-056Y0.csv
#         0156-M-050Y0.jpg
#         0203-M-081Y0.csv
#         0420-F-079Y0.csv
#         0052-F-026Y0.csv
#         0235-F-073Y0.csv
#         0398-F-070Y0.csv
#         0311-F-074Y0.jpg
#         0333-F-070Y0.csv
#         0440-F-030Y0.jpg
#         0242-M-066Y0.csv
#         0226-M-060Y0.csv
#         0280-F-051Y0.csv
#         0233-F-064Y0.csv
#         0284-F-061Y0.jpg
#         0162-M-084Y0.csv
#         0262-F-084Y0.csv
#         0060-F-013Y0.jpg
#         0497-M-027Y0.csv
#         0155-F-067Y0.csv
#         0413-M-036Y0.jpg
#         0025-F-015Y0.csv
#         0159-M-062Y0.csv
#         0214-F-072Y0.csv
#         0471-M-081Y0.csv
#         0464-F-074Y0.jpg
#         0287-M-078Y0.csv
#         0439-M-044Y0.csv
#         0036-F-016Y0.csv
#         0488-F-050Y0.csv
#         0179-F-072Y0.jpg
#         0057-F-030Y0.jpg
#         0496-F-055Y0.csv
#         0173-F-079Y0.csv
#         0180-M-082Y0.jpg
#         0268-M-052Y0.csv
#         0177-F-037Y0.csv
#         0197-F-077Y0.csv
#         0282-F-034Y0.jpg
#         0162-M-084Y0.jpg
#         0293-M-068Y0.jpg
#         0336-M-050Y0.csv
#         0042-F-019Y0.csv
#         0409-F-043Y0.jpg
#         0108-F-036Y0.jpg
#         0466-F-046Y0.jpg
#         0254-F-064Y0.csv
#         0264-F-044Y0.jpg
#         0444-F-020Y0.jpg
#         0278-F-055Y0.jpg
#         0485-M-062Y0.csv
#         0424-M-074Y0.jpg
#         0417-F-069Y0.jpg
#         0222-F-051Y0.csv
#         0342-F-060Y0.csv
#         0313-M-036Y0.csv
#         0481-F-051Y0.jpg
#         0390-M-080Y0.jpg
#         0109-F-042Y0.jpg
#         0466-F-046Y0.csv
#         0255-F-053Y0.jpg
#         0335-F-079Y0.csv
#         0278-F-055Y0.csv
#         0393-M-064Y0.csv
#         0101-F-022Y0.csv
#         0241-F-078Y0.jpg
#         0474-M-027Y0.jpg
#         0035-M-026Y0.jpg
#         0048-F-020Y0.csv
#         0386-M-071Y0.csv
#         0307-F-072Y0.jpg
#         0277-F-050Y0.jpg
#         0145-F-047Y0.csv
#         0337-M-027Y0.jpg
#         0011-F-063Y0.csv
#         0446-M-060Y0.csv
#         0159-M-062Y0.jpg
#         0023-F-014Y0.jpg
#         0135-F-024Y0.csv
#         0492-F-051Y0.jpg
#         0474-M-027Y0.csv
#         0025-F-015Y0.jpg
#         0105-F-009Y0.csv
#         0382-M-028Y0.csv
#         0311-F-074Y0.csv
#         0181-M-069Y0.csv
#         0475-M-053Y0.jpg
#         0090-F-016Y0.jpg
#         0073-F-036Y0.csv
#         0121-F-072Y0.csv
#         0341-F-038Y0.csv
#         0225-M-086Y0.jpg
#         0450-F-072Y0.jpg
#         0095-F-020Y0.csv
#         0212-F-049Y0.csv
#         0021-F-079Y0.csv
#         0154-M-078Y0.jpg
#         0305-F-025Y0.csv
#         0164-F-064Y0.csv
#         0442-F-021Y0.csv
#         0234-F-073Y0.jpg
#         0418-F-025Y0.csv
#         0334-F-058Y0.csv
#         0467-F-025Y0.jpg
#         0397-M-023Y0.jpg
#         0046-F-021Y0.jpg
#         0406-F-067Y0.jpg
#         0202-F-068Y0.csv
#         0104-F-013Y0.csv
#         0139-F-077Y0.jpg
#         0024-F-014Y0.csv
#         0038-F-020Y0.csv
#         0210-F-079Y0.jpg
#         0235-F-073Y0.jpg
#         0248-F-058Y0.jpg
#         0200-M-065Y0.csv
#         0434-M-041Y0.jpg
#         0034-F-067Y0.csv
#         0010-F-037Y0.csv
#         0155-F-067Y0.jpg
#         0303-M-044Y0.jpg
#         0282-F-034Y0.csv
#         0271-F-062Y0.csv
#         0301-F-036Y0.csv
#         0161-F-054Y0.csv
#         0436-F-054Y0.jpg
#         0168-M-055Y0.csv
#         0165-M-078Y0.jpg
#         0269-M-062Y0.jpg
#         0427-F-050Y0.jpg
#         0153-M-021Y0.jpg
#         0343-M-031Y0.jpg
#         0451-F-066Y0.jpg
#         0252-M-056Y0.csv
#         0447-M-067Y0.csv
#         0296-F-039Y0.csv
#         0163-F-053Y0.csv
#         0016-F-023Y0.jpg
#         0315-F-067Y0.csv
#         0395-M-080Y0.jpg
#         0097-F-040Y0.csv
#         0387-M-046Y0.csv
#         0422-F-088Y0.csv
#         0205-M-063Y0.jpg
#         0243-M-068Y0.jpg
#         0204-F-084Y0.jpg
#         0283-M-030Y0.csv
#         0319-F-040Y0.csv
#         0011-F-063Y0.jpg
#         0207-F-061Y0.csv
#         0433-F-021Y0.csv
#         0153-M-021Y0.csv
#         0228-F-057Y0.csv
#         0172-F-078Y0.jpg
#         0281-M-052Y0.jpg
#         0145-F-047Y0.jpg
#         0174-M-063Y0.csv
#         0181-M-069Y0.jpg
#         0219-F-077Y0.csv
#         0477-F-075Y0.jpg
#         0401-M-049Y0.jpg
#         0389-F-063Y0.csv
#         0301-F-036Y0.jpg
#         0144-F-038Y0.csv
#         0186-F-042Y0.csv
#         0055-F-032Y0.jpg
#         0308-M-067Y0.jpg
#         0213-F-086Y0.csv
#         0312-M-036Y0.jpg
#         0450-F-072Y0.csv
#         0220-F-069Y0.csv
#         0405-F-060Y0.jpg
#         0271-F-062Y0.jpg
#         0179-F-072Y0.csv
#         0170-M-074Y0.jpg
#         0478-F-034Y0.csv
#         0479-F-033Y0.csv
#         0316-F-074Y0.jpg
#         0147-F-086Y0.jpg
#         0261-F-056Y0.csv
#         0026-F-029Y0.csv
#         0471-M-081Y0.jpg
#         0426-F-063Y0.jpg
#         0245-F-086Y0.jpg
#         0501-M-080Y0.jpg
#         0258-F-058Y0.jpg
#         0015-M-020Y0.csv
#         0050-F-015Y0.csv
#         0272-M-035Y0.csv
#         0449-F-059Y0.csv
#         0254-F-064Y0.jpg
#         0154-M-078Y0.csv
#         0169-F-044Y0.jpg
#         0438-F-062Y0.jpg
#         0484-F-057Y0.jpg
#         0302-F-068Y0.csv
#         0063-F-036Y0.jpg
#         0432-F-054Y0.jpg
#         0464-F-074Y0.csv
#         0486-M-033Y0.jpg
#         0488-F-050Y0.jpg
#         0078-F-016Y0.jpg
#         0135-F-024Y0.jpg
#         0197-F-077Y0.jpg
#         0484-F-057Y0.csv
#         0049-F-013Y0.csv
#         0033-F-023Y0.jpg
#         0227-M-055Y0.csv
#         0398-F-070Y0.jpg
#         0008-M-022Y0.jpg
#         0397-M-023Y0.csv
#         0231-F-056Y0.jpg
#         0454-F-040Y0.jpg
#         0400-F-024Y0.jpg
#         0253-F-055Y0.jpg
#         0390-M-080Y0.csv
#         0385-F-071Y0.jpg
#         0455-F-078Y0.csv
#         0221-F-066Y0.jpg
#         0100-M-051Y0.csv
#         0243-M-068Y0.csv
#         0059-F-028Y0.jpg
#         0081-M-022Y0.jpg
#         0251-M-055Y0.csv
#         0020-M-030Y0.csv
#         0040-M-023Y0.csv
#         0483-F-018Y0.jpg
#         0202-F-068Y0.jpg
#         0242-M-066Y0.jpg
#         0267-F-065Y0.jpg
#         0017-F-040Y0.jpg
#         0455-F-078Y0.jpg
#         0384-F-078Y0.jpg
#         0183-F-080Y0.csv
#         0069-M-039Y0.jpg
#         0403-M-039Y0.csv
#         0389-F-063Y0.jpg
#         0191-F-066Y0.csv
#         0491-F-018Y0.csv
#         0470-F-065Y0.csv
#         0280-F-051Y0.jpg
#         0156-M-050Y0.csv
#         0338-F-027Y0.csv
#         0008-M-022Y0.csv
#         0013-M-022Y0.csv
#         0394-F-062Y0.csv
#         0460-F-019Y0.jpg
#         0196-F-051Y0.jpg
#         0275-M-074Y0.jpg
#         0380-M-060Y0.csv
#         0067-F-028Y0.csv
#         0261-F-056Y0.jpg
#         0283-M-030Y0.jpg
#         0322-F-061Y0.csv
#         0158-F-072Y0.jpg
#         0182-F-059Y0.jpg
#         0071-F-016Y0.csv
#         0345-M-064Y0.jpg
#         0195-F-064Y0.csv
#         0433-F-021Y0.jpg
#         0391-M-046Y0.jpg
#         0056-F-069Y0.jpg
#         0478-F-034Y0.jpg
#         0296-F-039Y0.jpg
#         0476-M-047Y0.jpg
#         0394-F-062Y0.jpg
#         0479-F-033Y0.jpg
#         0422-F-088Y0.jpg
#         0017-F-040Y0.csv
#         0180-M-082Y0.csv
#         0069-M-039Y0.csv
#         0441-M-044Y0.csv
#         0425-M-062Y0.jpg
#         0277-F-050Y0.csv
#         0470-F-065Y0.jpg
#         0188-F-066Y0.jpg
#         0285-F-061Y0.csv
#         0142-F-051Y0.jpg
#         0276-F-076Y0.jpg
#         0330-M-049Y0.csv
#         0423-M-065Y0.jpg
#         0495-M-048Y0.csv
#         0226-M-060Y0.jpg
#         0143-F-089Y0.csv
#         0451-F-066Y0.csv
#         0341-F-038Y0.jpg
#         0001-F-037Y0.jpg
#         0325-M-039Y0.jpg
#         0134-M-038Y0.csv
#         0108-F-036Y0.csv
#         0337-M-027Y0.csv
#         0477-F-075Y0.csv
#         0079-F-012Y0.csv
#         0435-M-045Y0.jpg
#         0236-M-065Y0.jpg
#         0126-F-026Y0.jpg
#         0056-F-069Y0.csv
#         0031-F-014Y0.csv
#         0388-M-073Y0.csv
#         0037-F-019Y0.csv
#         0098-F-065Y0.jpg
#         0184-M-034Y0.jpg
#         0294-F-068Y0.csv
#         0126-F-026Y0.csv
#         0430-M-060Y0.csv
#         0393-M-064Y0.jpg
#         0220-F-069Y0.jpg
#         0240-F-061Y0.jpg
#         0054-F-079Y0.jpg
#         0265-F-081Y0.csv
#         0496-F-055Y0.jpg
#         0453-F-064Y0.csv
#         0250-F-069Y0.jpg
#         0138-M-064Y0.csv
#         0065-F-032Y0.jpg
#         0424-M-074Y0.csv
#         0174-M-063Y0.jpg
#         0003-F-013Y0.jpg
#         0143-F-089Y0.jpg
#         0430-M-060Y0.jpg
#         0187-F-067Y0.jpg
#         0227-M-055Y0.jpg
#         0140-M-024Y0.csv
#         0487-F-047Y0.jpg
#         0300-M-083Y0.csv
#         0097-F-040Y0.jpg
#         0022-M-006Y0.jpg
#         0276-F-076Y0.csv
#         0388-M-073Y0.jpg
#         0209-M-072Y0.jpg
#         0054-F-079Y0.csv
#         0062-F-041Y0.jpg
#         0051-F-066Y0.jpg
#         0342-F-060Y0.jpg
#         0029-M-019Y0.csv
#         0111-F-033Y0.jpg
#         0157-M-060Y0.csv
#         0481-F-051Y0.csv
#     annotations/
#         0398-F-070Y0.txt
#         0301-F-036Y1.txt
#         0021-F-079Y1.txt
#         0025-F-015Y0.txt
#         0484-F-057Y0.txt
#         0090-F-016Y1.txt
#         0262-F-084Y1.txt
#         0015-M-020Y1.txt
#         0240-F-061Y0.txt
#         0213-F-086Y1.txt
#         0451-F-066Y0.txt
#         0471-M-081Y0.txt
#         0219-F-077Y1.txt
#         0478-F-034Y0.txt
#         0455-F-078Y1.txt
#         0154-M-078Y0.txt
#         0438-F-062Y0.txt
#         0388-M-073Y1.txt
#         0225-M-086Y1.txt
#         0140-M-024Y1.txt
#         0312-M-036Y1.txt
#         0168-M-055Y1.txt
#         0450-F-072Y0.txt
#         0180-M-082Y1.txt
#         0501-M-080Y1.txt
#         0485-M-062Y0.txt
#         0334-F-058Y0.txt
#         0447-M-067Y1.txt
#         0333-F-070Y1.txt
#         0245-F-086Y0.txt
#         0060-F-013Y0.txt
#         0278-F-055Y1.txt
#         0001-F-037Y1.txt
#         0156-M-050Y1.txt
#         0042-F-019Y0.txt
#         0363-F-062Y1.txt
#         0421-F-083Y0.txt
#         0057-F-030Y0.txt
#         0271-F-062Y1.txt
#         0139-F-077Y1.txt
#         0165-M-078Y0.txt
#         0474-M-027Y0.txt
#         0415-F-061Y1.txt
#         0253-F-055Y0.txt
#         0457-F-055Y1.txt
#         0391-M-046Y0.txt
#         0170-M-074Y1.txt
#         0419-F-022Y0.txt
#         0018-F-020Y0.txt
#         0008-M-022Y1.txt
#         0199-F-035Y1.txt
#         0089-F-012Y0.txt
#         0483-F-018Y0.txt
#         0038-F-020Y0.txt
#         0263-F-049Y1.txt
#         0090-F-016Y0.txt
#         0239-F-073Y0.txt
#         0335-F-079Y1.txt
#         0324-F-061Y1.txt
#         0010-F-037Y0.txt
#         0464-F-074Y0.txt
#         0403-M-039Y1.txt
#         0391-M-046Y1.txt
#         0052-F-026Y1.txt
#         0044-F-022Y0.txt
#         0248-F-058Y0.txt
#         0033-F-023Y1.txt
#         0411-F-066Y1.txt
#         0475-M-053Y1.txt
#         0194-F-077Y1.txt
#         0061-F-021Y0.txt
#         0061-F-021Y1.txt
#         0004-F-010Y1.txt
#         0081-M-022Y0.txt
#         0490-F-038Y0.txt
#         0098-F-065Y1.txt
#         0430-M-060Y1.txt
#         0066-F-019Y1.txt
#         0437-F-065Y1.txt
#         0427-F-050Y1.txt
#         0169-F-044Y1.txt
#         0293-M-068Y1.txt
#         0033-F-023Y0.txt
#         0308-M-067Y0.txt
#         0168-M-055Y0.txt
#         0323-M-054Y1.txt
#         0242-M-066Y1.txt
#         0453-F-064Y1.txt
#         0452-M-042Y0.txt
#         0197-F-077Y0.txt
#         0153-M-021Y1.txt
#         0393-M-064Y0.txt
#         0246-M-027Y1.txt
#         0294-F-068Y0.txt
#         0182-F-059Y1.txt
#         0126-F-026Y0.txt
#         0468-F-073Y1.txt
#         0296-F-039Y1.txt
#         0189-M-068Y1.txt
#         0299-F-060Y1.txt
#         0138-M-064Y1.txt
#         0381-F-062Y0.txt
#         0388-M-073Y0.txt
#         0118-F-015Y0.txt
#         0175-M-053Y0.txt
#         0310-F-072Y1.txt
#         0249-F-074Y0.txt
#         0253-F-055Y1.txt
#         0491-F-018Y1.txt
#         0442-F-021Y0.txt
#         0081-M-022Y1.txt
#         0265-F-081Y0.txt
#         0060-F-013Y1.txt
#         0460-F-019Y1.txt
#         0477-F-075Y1.txt
#         0238-F-067Y1.txt
#         0275-M-074Y1.txt
#         0481-F-051Y0.txt
#         0343-M-031Y1.txt
#         0303-M-044Y0.txt
#         0261-F-056Y1.txt
#         0019-F-015Y1.txt
#         0470-F-065Y0.txt
#         0487-F-047Y0.txt
#         0481-F-051Y1.txt
#         0048-F-020Y0.txt
#         0017-F-040Y0.txt
#         0146-M-057Y0.txt
#         0405-F-060Y0.txt
#         0326-F-026Y0.txt
#         0443-M-020Y1.txt
#         0461-F-019Y1.txt
#         0387-M-046Y0.txt
#         0162-M-084Y0.txt
#         0055-F-032Y1.txt
#         0195-F-064Y0.txt
#         0021-F-079Y0.txt
#         0436-F-054Y1.txt
#         0214-F-072Y0.txt
#         0301-F-036Y0.txt
#         0228-F-057Y0.txt
#         0395-M-080Y1.txt
#         0175-M-053Y1.txt
#         0465-F-040Y1.txt
#         0181-M-069Y1.txt
#         0204-F-084Y1.txt
#         0109-F-042Y1.txt
#         0064-F-017Y1.txt
#         0105-F-009Y0.txt
#         0272-M-035Y0.txt
#         0227-M-055Y0.txt
#         0208-F-058Y1.txt
#         0486-M-033Y0.txt
#         0144-F-038Y0.txt
#         0272-M-035Y1.txt
#         0302-F-068Y1.txt
#         0282-F-034Y1.txt
#         0169-F-044Y0.txt
#         0145-F-047Y1.txt
#         0325-M-039Y0.txt
#         0329-M-051Y1.txt
#         0013-M-022Y0.txt
#         0328-M-083Y0.txt
#         0209-M-072Y0.txt
#         0273-M-056Y1.txt
#         0078-F-016Y1.txt
#         0243-M-068Y1.txt
#         0431-F-066Y1.txt
#         0048-F-020Y1.txt
#         0025-F-015Y1.txt
#         0185-F-073Y0.txt
#         0219-F-077Y0.txt
#         0283-M-030Y1.txt
#         0315-F-067Y1.txt
#         0345-M-064Y1.txt
#         0214-F-072Y1.txt
#         0138-M-064Y0.txt
#         0097-F-040Y1.txt
#         0423-M-065Y1.txt
#         0439-M-044Y0.txt
#         0415-F-061Y0.txt
#         0286-F-065Y1.txt
#         0300-M-083Y0.txt
#         0007-F-006Y1.txt
#         0059-F-028Y1.txt
#         0455-F-078Y0.txt
#         0141-M-055Y1.txt
#         0471-M-081Y1.txt
#         0250-F-069Y1.txt
#         0246-M-027Y0.txt
#         0108-F-036Y1.txt
#         0491-F-018Y0.txt
#         0158-F-072Y0.txt
#         0118-F-015Y1.txt
#         0166-F-071Y0.txt
#         0406-F-067Y1.txt
#         0427-F-050Y0.txt
#         0492-F-051Y1.txt
#         0459-F-042Y0.txt
#         0385-F-071Y1.txt
#         0049-F-013Y1.txt
#         0064-F-017Y0.txt
#         0297-F-031Y1.txt
#         0218-M-067Y0.txt
#         0185-F-073Y1.txt
#         0146-M-057Y1.txt
#         0438-F-062Y1.txt
#         0418-F-025Y1.txt
#         0079-F-012Y1.txt
#         0066-F-019Y0.txt
#         0032-F-007Y1.txt
#         0459-F-042Y1.txt
#         0314-M-015Y1.txt
#         0050-F-015Y1.txt
#         0111-F-033Y0.txt
#         0394-F-062Y0.txt
#         0147-F-086Y1.txt
#         0139-F-077Y0.txt
#         0342-F-060Y0.txt
#         0300-M-083Y1.txt
#         0112-F-064Y1.txt
#         0401-M-049Y0.txt
#         0200-M-065Y0.txt
#         0003-F-013Y0.txt
#         0482-F-065Y0.txt
#         0164-F-064Y1.txt
#         0188-F-066Y1.txt
#         0072-F-035Y0.txt
#         0495-M-048Y1.txt
#         0463-F-020Y1.txt
#         0258-F-058Y0.txt
#         0297-F-031Y0.txt
#         0457-F-055Y0.txt
#         0057-F-030Y1.txt
#         0401-M-049Y1.txt
#         0046-F-021Y1.txt
#         0223-F-063Y1.txt
#         0380-M-060Y1.txt
#         0098-F-065Y0.txt
#         0332-M-084Y0.txt
#         0384-F-078Y0.txt
#         0135-F-024Y0.txt
#         0436-F-054Y0.txt
#         0100-M-051Y0.txt
#         0229-F-078Y1.txt
#         0469-F-068Y0.txt
#         0105-F-009Y1.txt
#         0207-F-061Y1.txt
#         0264-F-044Y0.txt
#         0416-F-022Y0.txt
#         0446-M-060Y1.txt
#         0104-F-013Y1.txt
#         0121-F-072Y1.txt
#         0152-F-026Y1.txt
#         0012-F-013Y1.txt
#         0179-F-072Y0.txt
#         0405-F-060Y1.txt
#         0107-F-033Y0.txt
#         0319-F-040Y1.txt
#         0247-F-063Y1.txt
#         0034-F-067Y1.txt
#         0165-M-078Y1.txt
#         0492-F-051Y0.txt
#         0340-M-056Y1.txt
#         0303-M-044Y1.txt
#         0104-F-013Y0.txt
#         0008-M-022Y0.txt
#         0100-M-051Y1.txt
#         0311-F-074Y0.txt
#         0499-F-065Y0.txt
#         0265-F-081Y1.txt
#         0252-M-056Y0.txt
#         0280-F-051Y1.txt
#         0210-F-079Y1.txt
#         0419-F-022Y1.txt
#         0441-M-044Y1.txt
#         0379-M-040Y0.txt
#         0249-F-074Y1.txt
#         0134-M-038Y1.txt
#         0379-M-040Y1.txt
#         0496-F-055Y1.txt
#         0233-F-064Y0.txt
#         0281-M-052Y0.txt
#         0483-F-018Y1.txt
#         0107-F-033Y1.txt
#         0067-F-028Y1.txt
#         0469-F-068Y1.txt
#         0095-F-020Y1.txt
#         0418-F-025Y0.txt
#         0284-F-061Y0.txt
#         0239-F-073Y1.txt
#         0484-F-057Y1.txt
#         0244-M-025Y1.txt
#         0479-F-033Y0.txt
#         0453-F-064Y0.txt
#         0329-M-051Y0.txt
#         0274-M-064Y0.txt
#         0028-F-041Y1.txt
#         0184-M-034Y0.txt
#         0112-F-064Y0.txt
#         0489-F-052Y1.txt
#         0447-M-067Y0.txt
#         0009-F-038Y1.txt
#         0183-F-080Y1.txt
#         0113-F-082Y1.txt
#         0113-F-082Y0.txt
#         0170-M-074Y0.txt
#         0024-F-014Y1.txt
#         0056-F-069Y1.txt
#         0444-F-020Y0.txt
#         0260-F-084Y0.txt
#         0181-M-069Y0.txt
#         0031-F-014Y0.txt
#         0251-M-055Y1.txt
#         0205-M-063Y1.txt
#         0382-M-028Y1.txt
#         0212-F-049Y0.txt
#         0295-F-074Y1.txt
#         0389-F-063Y0.txt
#         0159-M-062Y1.txt
#         0497-M-027Y1.txt
#         0277-F-050Y1.txt
#         0028-F-041Y0.txt
#         0342-F-060Y1.txt
#         0393-M-064Y1.txt
#         0191-F-066Y0.txt
#         0150-F-081Y1.txt
#         0273-M-056Y0.txt
#         0486-M-033Y1.txt
#         0004-F-010Y0.txt
#         0141-M-055Y0.txt
#         0291-M-073Y0.txt
#         0292-F-058Y0.txt
#         0163-F-053Y0.txt
#         0344-F-058Y1.txt
#         0159-M-062Y0.txt
#         0490-F-038Y1.txt
#         0013-M-022Y1.txt
#         0494-F-066Y0.txt
#         0316-F-074Y0.txt
#         0254-F-064Y0.txt
#         0285-F-061Y1.txt
#         0166-F-071Y1.txt
#         0036-F-016Y0.txt
#         0063-F-036Y0.txt
#         0428-F-077Y0.txt
#         0394-F-062Y1.txt
#         0005-F-025Y0.txt
#         0043-F-039Y1.txt
#         0145-F-047Y0.txt
#         0247-F-063Y0.txt
#         0202-F-068Y1.txt
#         0279-M-043Y1.txt
#         0212-F-049Y1.txt
#         0054-F-079Y1.txt
#         0334-F-058Y1.txt
#         0432-F-054Y1.txt
#         0179-F-072Y1.txt
#         0420-F-079Y1.txt
#         0248-F-058Y1.txt
#         0488-F-050Y1.txt
#         0204-F-084Y0.txt
#         0250-F-069Y0.txt
#         0470-F-065Y1.txt
#         0095-F-020Y0.txt
#         0136-F-027Y1.txt
#         0298-M-011Y1.txt
#         0322-F-061Y1.txt
#         0402-F-042Y1.txt
#         0245-F-086Y1.txt
#         0018-F-020Y1.txt
#         0432-F-054Y0.txt
#         0143-F-089Y1.txt
#         0068-F-017Y1.txt
#         0323-M-054Y0.txt
#         0032-F-007Y0.txt
#         0259-F-073Y0.txt
#         0477-F-075Y0.txt
#         0479-F-033Y1.txt
#         0041-F-019Y0.txt
#         0111-F-033Y1.txt
#         0413-M-036Y0.txt
#         0051-F-066Y1.txt
#         0318-F-053Y0.txt
#         0380-M-060Y0.txt
#         0480-M-052Y0.txt
#         0468-F-073Y0.txt
#         0337-M-027Y0.txt
#         0164-F-064Y0.txt
#         0420-F-079Y0.txt
#         0466-F-046Y1.txt
#         0172-F-078Y1.txt
#         0326-F-026Y1.txt
#         0114-F-038Y0.txt
#         0498-M-054Y1.txt
#         0435-M-045Y0.txt
#         0173-F-079Y1.txt
#         0268-M-052Y0.txt
#         0236-M-065Y1.txt
#         0399-M-023Y1.txt
#         0409-F-043Y0.txt
#         0386-M-071Y0.txt
#         0261-F-056Y0.txt
#         0241-F-078Y1.txt
#         0014-F-062Y0.txt
#         0206-F-070Y0.txt
#         0162-M-084Y1.txt
#         0222-F-051Y1.txt
#         0440-F-030Y0.txt
#         0041-F-019Y1.txt
#         0256-M-056Y0.txt
#         0268-M-052Y1.txt
#         0444-F-020Y1.txt
#         0172-F-078Y0.txt
#         0485-M-062Y1.txt
#         0108-F-036Y0.txt
#         0173-F-079Y0.txt
#         0325-M-039Y1.txt
#         0065-F-032Y0.txt
#         0171-M-058Y1.txt
#         0474-M-027Y1.txt
#         0395-M-080Y0.txt
#         0151-M-079Y1.txt
#         0251-M-055Y0.txt
#         0089-F-012Y1.txt
#         0500-M-033Y1.txt
#         0409-F-043Y1.txt
#         0498-M-054Y0.txt
#         0029-M-019Y0.txt
#         0005-F-025Y1.txt
#         0071-F-016Y0.txt
#         0180-M-082Y0.txt
#         0324-F-061Y0.txt
#         0231-F-056Y1.txt
#         0073-F-036Y1.txt
#         0319-F-040Y0.txt
#         0150-F-081Y0.txt
#         0069-M-039Y0.txt
#         0056-F-069Y0.txt
#         0400-F-024Y0.txt
#         0259-F-073Y1.txt
#         0396-F-053Y0.txt
#         0489-F-052Y0.txt
#         0020-M-030Y1.txt
#         0377-F-045Y0.txt
#         0044-F-022Y1.txt
#         0451-F-066Y1.txt
#         0264-F-044Y1.txt
#         0475-M-053Y0.txt
#         0305-F-025Y0.txt
#         0043-F-039Y0.txt
#         0463-F-020Y0.txt
#         0279-M-043Y0.txt
#         0201-F-077Y1.txt
#         0428-F-077Y1.txt
#         0321-F-069Y1.txt
#         0313-M-036Y0.txt
#         0267-F-065Y1.txt
#         0287-M-078Y0.txt
#         0046-F-021Y0.txt
#         0421-F-083Y1.txt
#         0271-F-062Y0.txt
#         0464-F-074Y1.txt
#         0398-F-070Y1.txt
#         0396-F-053Y1.txt
#         0167-F-049Y1.txt
#         0286-F-065Y0.txt
#         0449-F-059Y0.txt
#         0102-F-013Y1.txt
#         0023-F-014Y1.txt
#         0466-F-046Y0.txt
#         0311-F-074Y1.txt
#         0062-F-041Y1.txt
#         0412-F-023Y0.txt
#         0435-M-045Y1.txt
#         0276-F-076Y1.txt
#         0053-F-040Y1.txt
#         0157-M-060Y1.txt
#         0412-F-023Y1.txt
#         0308-M-067Y1.txt
#         0333-F-070Y0.txt
#         0171-M-058Y0.txt
#         0026-F-029Y0.txt
#         0426-F-063Y1.txt
#         0298-M-011Y0.txt
#         0283-M-030Y0.txt
#         0302-F-068Y0.txt
#         0152-F-026Y0.txt
#         0338-F-027Y0.txt
#         0397-M-023Y0.txt
#         0187-F-067Y0.txt
#         0480-M-052Y1.txt
#         0465-F-040Y0.txt
#         0020-M-030Y0.txt
#         0460-F-019Y0.txt
#         0210-F-079Y0.txt
#         0425-M-062Y0.txt
#         0287-M-078Y1.txt
#         0472-F-070Y1.txt
#         0411-F-066Y0.txt
#         0439-M-044Y1.txt
#         0049-F-013Y0.txt
#         0222-F-051Y0.txt
#         0458-M-020Y1.txt
#         0230-F-078Y1.txt
#         0454-F-040Y0.txt
#         0070-F-027Y1.txt
#         0387-M-046Y1.txt
#         0386-M-071Y1.txt
#         0077-F-018Y0.txt
#         0163-F-053Y1.txt
#         0304-M-068Y0.txt
#         0142-F-051Y1.txt
#         0424-M-074Y1.txt
#         0336-M-050Y0.txt
#         0234-F-073Y0.txt
#         0194-F-077Y0.txt
#         0467-F-025Y1.txt
#         0040-M-023Y0.txt
#         0276-F-076Y0.txt
#         0493-F-029Y1.txt
#         0143-F-089Y0.txt
#         0001-F-037Y0.txt
#         0211-F-055Y1.txt
#         0054-F-079Y0.txt
#         0031-F-014Y1.txt
#         0155-F-067Y0.txt
#         0196-F-051Y0.txt
#         0450-F-072Y1.txt
#         0155-F-067Y1.txt
#         0318-F-053Y1.txt
#         0234-F-073Y1.txt
#         0413-M-036Y1.txt
#         0226-M-060Y0.txt
#         0499-F-065Y1.txt
#         0203-M-081Y1.txt
#         0363-F-062Y0.txt
#         0011-F-063Y0.txt
#         0029-M-019Y1.txt
#         0482-F-065Y1.txt
#         0230-F-078Y0.txt
#         0316-F-074Y1.txt
#         0147-F-086Y0.txt
#         0416-F-022Y1.txt
#         0304-M-068Y1.txt
#         0223-F-063Y0.txt
#         0441-M-044Y0.txt
#         0422-F-088Y1.txt
#         0399-M-023Y0.txt
#         0496-F-055Y0.txt
#         0227-M-055Y1.txt
#         0177-F-037Y0.txt
#         0149-M-062Y0.txt
#         0344-F-058Y0.txt
#         0322-F-061Y0.txt
#         0055-F-032Y0.txt
#         0384-F-078Y1.txt
#         0011-F-063Y1.txt
#         0198-F-063Y0.txt
#         0449-F-059Y1.txt
#         0038-F-020Y1.txt
#         0235-F-073Y1.txt
#         0320-M-069Y0.txt
#         0106-F-016Y0.txt
#         0280-F-051Y0.txt
#         0406-F-067Y0.txt
#         0284-F-061Y1.txt
#         0445-F-021Y1.txt
#         0205-M-063Y0.txt
#         0454-F-040Y1.txt
#         0167-F-049Y0.txt
#         0077-F-018Y1.txt
#         0026-F-029Y1.txt
#         0462-M-041Y0.txt
#         0220-F-069Y0.txt
#         0187-F-067Y1.txt
#         0203-M-081Y0.txt
#         0430-M-060Y0.txt
#         0433-F-021Y0.txt
#         0290-F-030Y0.txt
#         0059-F-028Y0.txt
#         0023-F-014Y0.txt
#         0102-F-013Y0.txt
#         0015-M-020Y0.txt
#         0188-F-066Y0.txt
#         0202-F-068Y0.txt
#         0186-F-042Y1.txt
#         0078-F-016Y0.txt
#         0067-F-028Y0.txt
#         0241-F-078Y0.txt
#         0050-F-015Y0.txt
#         0340-M-056Y0.txt
#         0198-F-063Y1.txt
#         0476-M-047Y1.txt
#         0472-F-070Y0.txt
#         0337-M-027Y1.txt
#         0429-M-083Y0.txt
#         0052-F-026Y0.txt
#         0255-F-053Y1.txt
#         0161-F-054Y0.txt
#         0310-F-072Y0.txt
#         0269-M-062Y1.txt
#         0197-F-077Y1.txt
#         0458-M-020Y0.txt
#         0382-M-028Y0.txt
#         0378-F-075Y1.txt
#         0071-F-016Y1.txt
#         0148-M-058Y0.txt
#         0255-F-053Y0.txt
#         0207-F-061Y0.txt
#         0501-M-080Y0.txt
#         0121-F-072Y0.txt
#         0010-F-037Y1.txt
#         0312-M-036Y0.txt
#         0236-M-065Y0.txt
#         0437-F-065Y0.txt
#         0267-F-065Y0.txt
#         0321-F-069Y0.txt
#         0037-F-019Y1.txt
#         0200-M-065Y1.txt
#         0221-F-066Y1.txt
#         0101-F-022Y0.txt
#         0036-F-016Y1.txt
#         0221-F-066Y0.txt
#         0035-M-026Y0.txt
#         0295-F-074Y0.txt
#         0003-F-013Y1.txt
#         0429-M-083Y1.txt
#         0389-F-063Y1.txt
#         0136-F-027Y0.txt
#         0254-F-064Y1.txt
#         0440-F-030Y1.txt
#         0240-F-061Y1.txt
#         0306-M-072Y1.txt
#         0488-F-050Y0.txt
#         0097-F-040Y0.txt
#         0014-F-062Y1.txt
#         0189-M-068Y0.txt
#         0142-F-051Y0.txt
#         0285-F-061Y0.txt
#         0047-F-023Y1.txt
#         0153-M-021Y0.txt
#         0495-M-048Y0.txt
#         0006-F-031Y0.txt
#         0051-F-066Y0.txt
#         0106-F-016Y1.txt
#         0062-F-041Y0.txt
#         0307-F-072Y1.txt
#         0034-F-067Y0.txt
#         0426-F-063Y0.txt
#         0154-M-078Y1.txt
#         0256-M-056Y1.txt
#         0424-M-074Y0.txt
#         0258-F-058Y1.txt
#         0493-F-029Y0.txt
#         0433-F-021Y1.txt
#         0037-F-019Y0.txt
#         0328-M-083Y1.txt
#         0397-M-023Y1.txt
#         0209-M-072Y1.txt
#         0040-M-023Y1.txt
#         0208-F-058Y0.txt
#         0282-F-034Y0.txt
#         0262-F-084Y0.txt
#         0330-M-049Y0.txt
#         0035-M-026Y1.txt
#         0476-M-047Y0.txt
#         0390-M-080Y1.txt
#         0281-M-052Y1.txt
#         0422-F-088Y0.txt
#         0417-F-069Y1.txt
#         0195-F-064Y1.txt
#         0434-M-041Y0.txt
#         0012-F-013Y0.txt
#         0019-F-015Y0.txt
#         0278-F-055Y0.txt
#         0332-M-084Y1.txt
#         0443-M-020Y0.txt
#         0497-M-027Y0.txt
#         0292-F-058Y1.txt
#         0053-F-040Y0.txt
#         0058-F-008Y0.txt
#         0296-F-039Y0.txt
#         0149-M-062Y1.txt
#         0381-F-062Y1.txt
#         0294-F-068Y1.txt
#         0235-F-073Y0.txt
#         0425-M-062Y1.txt
#         0402-F-042Y0.txt
#         0263-F-049Y0.txt
#         0225-M-086Y0.txt
#         0201-F-077Y0.txt
#         0417-F-069Y0.txt
#         0461-F-019Y0.txt
#         0186-F-042Y0.txt
#         0243-M-068Y0.txt
#         0007-F-006Y0.txt
#         0445-F-021Y0.txt
#         0306-M-072Y0.txt
#         0305-F-025Y1.txt
#         0101-F-022Y1.txt
#         0315-F-067Y0.txt
#         0307-F-072Y0.txt
#         0229-F-078Y0.txt
#         0157-M-060Y0.txt
#         0047-F-023Y0.txt
#         0277-F-050Y0.txt
#         0079-F-012Y0.txt
#         0403-M-039Y0.txt
#         0288-M-077Y1.txt
#         0072-F-035Y1.txt
#         0196-F-051Y1.txt
#         0442-F-021Y1.txt
#         0320-M-069Y1.txt
#         0288-M-077Y0.txt
#         0313-M-036Y1.txt
#         0228-F-057Y1.txt
#         0218-M-067Y1.txt
#         0161-F-054Y1.txt
#         0058-F-008Y1.txt
#         0462-M-041Y1.txt
#         0423-M-065Y0.txt
#         0434-M-041Y1.txt
#         0238-F-067Y0.txt
#         0341-F-038Y1.txt
#         0126-F-026Y1.txt
#         0191-F-066Y1.txt
#         0065-F-032Y1.txt
#         0231-F-056Y0.txt
#         0144-F-038Y1.txt
#         0233-F-064Y1.txt
#         0431-F-066Y0.txt
#         0068-F-017Y0.txt
#         0242-M-066Y0.txt
#         0022-M-006Y0.txt
#         0260-F-084Y1.txt
#         0314-M-015Y0.txt
#         0182-F-059Y0.txt
#         0016-F-023Y0.txt
#         0446-M-060Y0.txt
#         0378-F-075Y0.txt
#         0199-F-035Y0.txt
#         0330-M-049Y1.txt
#         0042-F-019Y1.txt
#         0385-F-071Y0.txt
#         0174-M-063Y1.txt
#         0177-F-037Y1.txt
#         0290-F-030Y1.txt
#         0174-M-063Y0.txt
#         0487-F-047Y1.txt
#         0063-F-036Y1.txt
#         0341-F-038Y0.txt
#         0114-F-038Y1.txt
#         0478-F-034Y1.txt
#         0335-F-079Y0.txt
#         0345-M-064Y0.txt
#         0293-M-068Y0.txt
#         0069-M-039Y1.txt
#         0500-M-033Y0.txt
#         0070-F-027Y0.txt
#         0151-M-079Y0.txt
#         0327-F-079Y1.txt
#         0226-M-060Y1.txt
#         0377-F-045Y1.txt
#         0140-M-024Y0.txt
#         0244-M-025Y0.txt
#         0327-F-079Y0.txt
#         0024-F-014Y0.txt
#         0016-F-023Y1.txt
#         0252-M-056Y1.txt
#         0452-M-042Y1.txt
#         0134-M-038Y0.txt
#         0343-M-031Y0.txt
#         0017-F-040Y1.txt
#         0073-F-036Y0.txt
#         0274-M-064Y1.txt
#         0494-F-066Y1.txt
#         0184-M-034Y1.txt
#         0338-F-027Y1.txt
#         0275-M-074Y0.txt
#         0206-F-070Y1.txt
#         0336-M-050Y1.txt
#         0006-F-031Y1.txt
#         0109-F-042Y0.txt
#         0390-M-080Y0.txt
#         0156-M-050Y0.txt
#         0299-F-060Y0.txt
#         0467-F-025Y0.txt
#         0211-F-055Y0.txt
#         0291-M-073Y1.txt
#         0148-M-058Y1.txt
#         0183-F-080Y0.txt
#         0009-F-038Y0.txt
#         0158-F-072Y1.txt
#         0135-F-024Y1.txt
#         0400-F-024Y1.txt
#         0213-F-086Y0.txt
#         0269-M-062Y0.txt
#         0022-M-006Y1.txt
#         0220-F-069Y1.txt
#     AP_YOLO_annotations/
#         0398-F-070Y0.txt
#         0025-F-015Y0.txt
#         0484-F-057Y0.txt
#         0240-F-061Y0.txt
#         0451-F-066Y0.txt
#         0471-M-081Y0.txt
#         0478-F-034Y0.txt
#         0154-M-078Y0.txt
#         0438-F-062Y0.txt
#         0450-F-072Y0.txt
#         0485-M-062Y0.txt
#         0334-F-058Y0.txt
#         0245-F-086Y0.txt
#         0060-F-013Y0.txt
#         0042-F-019Y0.txt
#         0421-F-083Y0.txt
#         0057-F-030Y0.txt
#         0165-M-078Y0.txt
#         0474-M-027Y0.txt
#         0253-F-055Y0.txt
#         0391-M-046Y0.txt
#         0419-F-022Y0.txt
#         0018-F-020Y0.txt
#         0089-F-012Y0.txt
#         0483-F-018Y0.txt
#         0038-F-020Y0.txt
#         0090-F-016Y0.txt
#         0239-F-073Y0.txt
#         0010-F-037Y0.txt
#         0464-F-074Y0.txt
#         0044-F-022Y0.txt
#         0248-F-058Y0.txt
#         0061-F-021Y0.txt
#         0081-M-022Y0.txt
#         0490-F-038Y0.txt
#         0033-F-023Y0.txt
#         0308-M-067Y0.txt
#         0168-M-055Y0.txt
#         0452-M-042Y0.txt
#         0197-F-077Y0.txt
#         0393-M-064Y0.txt
#         0294-F-068Y0.txt
#         0126-F-026Y0.txt
#         0381-F-062Y0.txt
#         0388-M-073Y0.txt
#         0118-F-015Y0.txt
#         0175-M-053Y0.txt
#         0249-F-074Y0.txt
#         0442-F-021Y0.txt
#         0265-F-081Y0.txt
#         0481-F-051Y0.txt
#         0303-M-044Y0.txt
#         0470-F-065Y0.txt
#         0487-F-047Y0.txt
#         0048-F-020Y0.txt
#         0017-F-040Y0.txt
#         0146-M-057Y0.txt
#         0405-F-060Y0.txt
#         0326-F-026Y0.txt
#         0387-M-046Y0.txt
#         0162-M-084Y0.txt
#         0195-F-064Y0.txt
#         0021-F-079Y0.txt
#         0214-F-072Y0.txt
#         0301-F-036Y0.txt
#         0228-F-057Y0.txt
#         0105-F-009Y0.txt
#         0272-M-035Y0.txt
#         0227-M-055Y0.txt
#         0486-M-033Y0.txt
#         0144-F-038Y0.txt
#         0169-F-044Y0.txt
#         0325-M-039Y0.txt
#         0013-M-022Y0.txt
#         0328-M-083Y0.txt
#         0209-M-072Y0.txt
#         0185-F-073Y0.txt
#         0219-F-077Y0.txt
#         0138-M-064Y0.txt
#         0439-M-044Y0.txt
#         0415-F-061Y0.txt
#         0300-M-083Y0.txt
#         0455-F-078Y0.txt
#         0246-M-027Y0.txt
#         0491-F-018Y0.txt
#         0158-F-072Y0.txt
#         0166-F-071Y0.txt
#         0427-F-050Y0.txt
#         0459-F-042Y0.txt
#         0064-F-017Y0.txt
#         0218-M-067Y0.txt
#         0066-F-019Y0.txt
#         0111-F-033Y0.txt
#         0394-F-062Y0.txt
#         0139-F-077Y0.txt
#         0342-F-060Y0.txt
#         0401-M-049Y0.txt
#         0200-M-065Y0.txt
#         0003-F-013Y0.txt
#         0482-F-065Y0.txt
#         0072-F-035Y0.txt
#         0258-F-058Y0.txt
#         0297-F-031Y0.txt
#         0457-F-055Y0.txt
#         0098-F-065Y0.txt
#         0332-M-084Y0.txt
#         0384-F-078Y0.txt
#         0135-F-024Y0.txt
#         0436-F-054Y0.txt
#         0100-M-051Y0.txt
#         0469-F-068Y0.txt
#         0264-F-044Y0.txt
#         0416-F-022Y0.txt
#         0179-F-072Y0.txt
#         0107-F-033Y0.txt
#         0492-F-051Y0.txt
#         0104-F-013Y0.txt
#         0008-M-022Y0.txt
#         0311-F-074Y0.txt
#         0499-F-065Y0.txt
#         0252-M-056Y0.txt
#         0379-M-040Y0.txt
#         0233-F-064Y0.txt
#         0281-M-052Y0.txt
#         0418-F-025Y0.txt
#         0284-F-061Y0.txt
#         0479-F-033Y0.txt
#         0453-F-064Y0.txt
#         0329-M-051Y0.txt
#         0274-M-064Y0.txt
#         0184-M-034Y0.txt
#         0112-F-064Y0.txt
#         0447-M-067Y0.txt
#         0113-F-082Y0.txt
#         0170-M-074Y0.txt
#         0444-F-020Y0.txt
#         0260-F-084Y0.txt
#         0181-M-069Y0.txt
#         0031-F-014Y0.txt
#         0212-F-049Y0.txt
#         0389-F-063Y0.txt
#         0028-F-041Y0.txt
#         0191-F-066Y0.txt
#         0273-M-056Y0.txt
#         0004-F-010Y0.txt
#         0141-M-055Y0.txt
#         0291-M-073Y0.txt
#         0292-F-058Y0.txt
#         0163-F-053Y0.txt
#         0159-M-062Y0.txt
#         0494-F-066Y0.txt
#         0316-F-074Y0.txt
#         0254-F-064Y0.txt
#         0036-F-016Y0.txt
#         0063-F-036Y0.txt
#         0428-F-077Y0.txt
#         0005-F-025Y0.txt
#         0145-F-047Y0.txt
#         0247-F-063Y0.txt
#         0204-F-084Y0.txt
#         0250-F-069Y0.txt
#         0095-F-020Y0.txt
#         0432-F-054Y0.txt
#         0323-M-054Y0.txt
#         0032-F-007Y0.txt
#         0259-F-073Y0.txt
#         0477-F-075Y0.txt
#         0041-F-019Y0.txt
#         0413-M-036Y0.txt
#         0318-F-053Y0.txt
#         0380-M-060Y0.txt
#         0480-M-052Y0.txt
#         0468-F-073Y0.txt
#         0337-M-027Y0.txt
#         0164-F-064Y0.txt
#         0420-F-079Y0.txt
#         0114-F-038Y0.txt
#         0435-M-045Y0.txt
#         0268-M-052Y0.txt
#         0409-F-043Y0.txt
#         0386-M-071Y0.txt
#         0261-F-056Y0.txt
#         0014-F-062Y0.txt
#         0206-F-070Y0.txt
#         0440-F-030Y0.txt
#         0256-M-056Y0.txt
#         0172-F-078Y0.txt
#         0108-F-036Y0.txt
#         0173-F-079Y0.txt
#         0065-F-032Y0.txt
#         0395-M-080Y0.txt
#         0251-M-055Y0.txt
#         0498-M-054Y0.txt
#         0029-M-019Y0.txt
#         0071-F-016Y0.txt
#         0180-M-082Y0.txt
#         0324-F-061Y0.txt
#         0319-F-040Y0.txt
#         0150-F-081Y0.txt
#         0069-M-039Y0.txt
#         0056-F-069Y0.txt
#         0400-F-024Y0.txt
#         0396-F-053Y0.txt
#         0489-F-052Y0.txt
#         0377-F-045Y0.txt
#         0475-M-053Y0.txt
#         0305-F-025Y0.txt
#         0043-F-039Y0.txt
#         0463-F-020Y0.txt
#         0279-M-043Y0.txt
#         0313-M-036Y0.txt
#         0287-M-078Y0.txt
#         0046-F-021Y0.txt
#         0271-F-062Y0.txt
#         0286-F-065Y0.txt
#         0449-F-059Y0.txt
#         0466-F-046Y0.txt
#         0412-F-023Y0.txt
#         0333-F-070Y0.txt
#         0171-M-058Y0.txt
#         0026-F-029Y0.txt
#         0298-M-011Y0.txt
#         0283-M-030Y0.txt
#         0302-F-068Y0.txt
#         0152-F-026Y0.txt
#         0338-F-027Y0.txt
#         0397-M-023Y0.txt
#         0187-F-067Y0.txt
#         0465-F-040Y0.txt
#         0020-M-030Y0.txt
#         0460-F-019Y0.txt
#         0210-F-079Y0.txt
#         0425-M-062Y0.txt
#         0411-F-066Y0.txt
#         0049-F-013Y0.txt
#         0222-F-051Y0.txt
#         0454-F-040Y0.txt
#         0077-F-018Y0.txt
#         0304-M-068Y0.txt
#         0336-M-050Y0.txt
#         0234-F-073Y0.txt
#         0194-F-077Y0.txt
#         0040-M-023Y0.txt
#         0276-F-076Y0.txt
#         0143-F-089Y0.txt
#         0001-F-037Y0.txt
#         0054-F-079Y0.txt
#         0155-F-067Y0.txt
#         0196-F-051Y0.txt
#         0226-M-060Y0.txt
#         0363-F-062Y0.txt
#         0011-F-063Y0.txt
#         0230-F-078Y0.txt
#         0147-F-086Y0.txt
#         0223-F-063Y0.txt
#         0441-M-044Y0.txt
#         0399-M-023Y0.txt
#         0496-F-055Y0.txt
#         0177-F-037Y0.txt
#         0149-M-062Y0.txt
#         0344-F-058Y0.txt
#         0322-F-061Y0.txt
#         0055-F-032Y0.txt
#         0198-F-063Y0.txt
#         0320-M-069Y0.txt
#         0106-F-016Y0.txt
#         0280-F-051Y0.txt
#         0406-F-067Y0.txt
#         0205-M-063Y0.txt
#         0167-F-049Y0.txt
#         0462-M-041Y0.txt
#         0220-F-069Y0.txt
#         0203-M-081Y0.txt
#         0430-M-060Y0.txt
#         0433-F-021Y0.txt
#         0290-F-030Y0.txt
#         0059-F-028Y0.txt
#         0023-F-014Y0.txt
#         0102-F-013Y0.txt
#         0015-M-020Y0.txt
#         0188-F-066Y0.txt
#         0202-F-068Y0.txt
#         0078-F-016Y0.txt
#         0067-F-028Y0.txt
#         0241-F-078Y0.txt
#         0050-F-015Y0.txt
#         0340-M-056Y0.txt
#         0472-F-070Y0.txt
#         0429-M-083Y0.txt
#         0052-F-026Y0.txt
#         0161-F-054Y0.txt
#         0310-F-072Y0.txt
#         0458-M-020Y0.txt
#         0382-M-028Y0.txt
#         0148-M-058Y0.txt
#         0255-F-053Y0.txt
#         0207-F-061Y0.txt
#         0501-M-080Y0.txt
#         0121-F-072Y0.txt
#         0312-M-036Y0.txt
#         0236-M-065Y0.txt
#         0437-F-065Y0.txt
#         0267-F-065Y0.txt
#         0321-F-069Y0.txt
#         0101-F-022Y0.txt
#         0221-F-066Y0.txt
#         0035-M-026Y0.txt
#         0295-F-074Y0.txt
#         0136-F-027Y0.txt
#         0488-F-050Y0.txt
#         0097-F-040Y0.txt
#         0189-M-068Y0.txt
#         0142-F-051Y0.txt
#         0285-F-061Y0.txt
# ...
#         0469-F-068Y1.csv
#         0018-F-020Y1.csv
#         0179-F-072Y1.jpg
#         0161-F-054Y1.csv
#         0101-F-022Y1.jpg
#         0321-F-069Y1.csv
#         0017-F-040Y1.jpg
#         0233-F-064Y1.csv
#         0155-F-067Y1.csv
#         0318-F-053Y1.jpg
#         0230-F-078Y1.csv
#         0068-F-017Y1.csv
#         0437-F-065Y1.jpg
#         0043-F-039Y1.csv
#         0049-F-013Y1.csv
#         0333-F-070Y1.jpg
#         0157-M-060Y1.csv
#         0007-F-006Y1.jpg
#         0294-F-068Y1.jpg
#         0173-F-079Y1.jpg
#         0050-F-015Y1.jpg
#         0152-F-026Y1.csv
#         0403-M-039Y1.csv
#         0422-F-088Y1.jpg
#         0303-M-044Y1.jpg
#         0229-F-078Y1.csv
#         0150-F-081Y1.csv
#         0170-M-074Y1.csv
#         0223-F-063Y1.csv
#         0461-F-019Y1.csv
#         0079-F-012Y1.jpg
#         0300-M-083Y1.csv
#         0231-F-056Y1.jpg
#         0437-F-065Y1.csv
#         0142-F-051Y1.jpg
#         0421-F-083Y1.csv
#         0444-F-020Y1.csv
#         0047-F-023Y1.csv
#         0419-F-022Y1.jpg
#         0089-F-012Y1.jpg
#         0121-F-072Y1.csv
#         0203-M-081Y1.csv
#         0276-F-076Y1.jpg
#         0328-M-083Y1.csv
#         0069-M-039Y1.csv
#         0229-F-078Y1.jpg
#         0141-M-055Y1.csv
#         0188-F-066Y1.jpg
#         0202-F-068Y1.csv
#         0145-F-047Y1.csv
#         0019-F-015Y1.csv
#         0057-F-030Y1.jpg
#         0434-M-041Y1.csv
#         0136-F-027Y1.csv
#         0196-F-051Y1.csv
#         0141-M-055Y1.jpg
#         0139-F-077Y1.csv
#         0175-M-053Y1.csv
#         0242-M-066Y1.csv
#         0016-F-023Y1.jpg
#         0214-F-072Y1.csv
#         0496-F-055Y1.csv
#         0415-F-061Y1.jpg
#         0166-F-071Y1.csv
#         0006-F-031Y1.jpg
#         0104-F-013Y1.jpg
#         0037-F-019Y1.jpg
#         0273-M-056Y1.jpg
#         0143-F-089Y1.jpg
#         0118-F-015Y1.csv
#         0455-F-078Y1.csv
#         0442-F-021Y1.csv
#         0500-M-033Y1.jpg
#         0480-M-052Y1.csv
#         0335-F-079Y1.jpg
#         0268-M-052Y1.jpg
#         0487-F-047Y1.jpg
#         0419-F-022Y1.csv
#         0429-M-083Y1.csv
#         0236-M-065Y1.csv
#         0253-F-055Y1.jpg
#         0336-M-050Y1.csv
#         0029-M-019Y1.csv
#         0479-F-033Y1.csv
#         0056-F-069Y1.csv
#         0107-F-033Y1.csv
#         0298-M-011Y1.csv
#         0465-F-040Y1.jpg
#         0497-M-027Y1.csv
#         0260-F-084Y1.jpg
#         0172-F-078Y1.csv
#         0251-M-055Y1.csv
#         0063-F-036Y1.jpg
#         0415-F-061Y1.csv
#         0067-F-028Y1.csv
#         0441-M-044Y1.jpg
#         0422-F-088Y1.csv
#         0269-M-062Y1.jpg
#         0320-M-069Y1.jpg
#         0152-F-026Y1.jpg
#         0384-F-078Y1.csv
#         0489-F-052Y1.jpg
#         0465-F-040Y1.csv
#         0147-F-086Y1.csv
#         0065-F-032Y1.csv
#         0255-F-053Y1.csv
#         0418-F-025Y1.csv
#         0008-M-022Y1.csv
#         0319-F-040Y1.csv
#         0058-F-008Y1.jpg
#         0174-M-063Y1.jpg
#         0297-F-031Y1.jpg
#         0037-F-019Y1.csv
#         0483-F-018Y1.jpg
#         0052-F-026Y1.csv
#         0447-M-067Y1.csv
#         0038-F-020Y1.csv
#         0470-F-065Y1.csv
#         0019-F-015Y1.jpg
#         0400-F-024Y1.jpg
#         0485-M-062Y1.csv
#         0194-F-077Y1.jpg
#         0159-M-062Y1.csv
#         0280-F-051Y1.jpg
#         0025-F-015Y1.csv
#         0344-F-058Y1.csv
#         0461-F-019Y1.jpg
#         0161-F-054Y1.jpg
#         0033-F-023Y1.csv
#         0472-F-070Y1.jpg
#         0329-M-051Y1.csv
#         0381-F-062Y1.jpg
#         0118-F-015Y1.jpg
#         0246-M-027Y1.jpg
#         0282-F-034Y1.jpg
#         0424-M-074Y1.csv
#         0411-F-066Y1.csv
#         0042-F-019Y1.jpg
#         0060-F-013Y1.jpg
#         0438-F-062Y1.jpg
#         0340-M-056Y1.csv
#         0458-M-020Y1.jpg
#         0167-F-049Y1.jpg
#         0213-F-086Y1.jpg
#         0416-F-022Y1.csv
#         0326-F-026Y1.csv
#         0335-F-079Y1.csv
#         0311-F-074Y1.jpg
#         0418-F-025Y1.jpg
#         0307-F-072Y1.jpg
#         0126-F-026Y1.csv
#         0098-F-065Y1.jpg
#         0202-F-068Y1.jpg
#         0090-F-016Y1.jpg
#         0474-M-027Y1.csv
#         0491-F-018Y1.csv
#         0234-F-073Y1.csv
#         0386-M-071Y1.csv
#         0158-F-072Y1.csv
#         0395-M-080Y1.csv
#         0273-M-056Y1.csv
#         0243-M-068Y1.jpg
#         0162-M-084Y1.csv
#         0031-F-014Y1.jpg
#         0051-F-066Y1.csv
#         0460-F-019Y1.csv
#         0062-F-041Y1.jpg
#         0256-M-056Y1.csv
#         0313-M-036Y1.csv
#         0486-M-033Y1.jpg
#         0154-M-078Y1.csv
#         0378-F-075Y1.jpg
#         0280-F-051Y1.csv
#         0070-F-027Y1.csv
#         0023-F-014Y1.jpg
#         0466-F-046Y1.csv
#         0295-F-074Y1.jpg
#         0077-F-018Y1.csv
#         0058-F-008Y1.csv
#         0205-M-063Y1.csv
#         0139-F-077Y1.jpg
#         0259-F-073Y1.csv
#         0386-M-071Y1.jpg
#         0195-F-064Y1.jpg
#         0499-F-065Y1.jpg
#         0073-F-036Y1.jpg
#         0073-F-036Y1.csv
#         0106-F-016Y1.jpg
#         0341-F-038Y1.jpg
#         0501-M-080Y1.csv
#         0028-F-041Y1.csv
#         0449-F-059Y1.csv
#         0297-F-031Y1.csv
#         0484-F-057Y1.csv
#         0250-F-069Y1.csv
#         0032-F-007Y1.jpg
#         0148-M-058Y1.jpg
#         0057-F-030Y1.csv
#         0298-M-011Y1.jpg
#         0182-F-059Y1.jpg
#         0380-M-060Y1.jpg
#         0089-F-012Y1.csv
#         0185-F-073Y1.jpg
#         0186-F-042Y1.csv
#         0102-F-013Y1.jpg
#         0061-F-021Y1.jpg
#         0040-M-023Y1.jpg
#         0287-M-078Y1.jpg
#         0105-F-009Y1.csv
#         0278-F-055Y1.csv
#         0189-M-068Y1.jpg
#         0446-M-060Y1.csv
#         0436-F-054Y1.jpg
#         0071-F-016Y1.csv
#         0314-M-015Y1.csv
#         0271-F-062Y1.jpg
#         0498-M-054Y1.jpg
#         0487-F-047Y1.csv
#         0287-M-078Y1.csv
#         0157-M-060Y1.jpg
#         0034-F-067Y1.csv
#         0485-M-062Y1.jpg
#         0001-F-037Y1.jpg
#         0226-M-060Y1.jpg
#         0221-F-066Y1.jpg
#         0276-F-076Y1.csv
#         0329-M-051Y1.jpg
#         0262-F-084Y1.csv
#         0342-F-060Y1.jpg
#         0163-F-053Y1.jpg
#         0198-F-063Y1.jpg
#         0072-F-035Y1.csv
#         0498-M-054Y1.csv
#         0416-F-022Y1.jpg
#         0452-M-042Y1.jpg
#         0194-F-077Y1.csv
#         0286-F-065Y1.csv
#         0172-F-078Y1.jpg
#         0413-M-036Y1.csv
#         0248-F-058Y1.csv
#         0403-M-039Y1.jpg
#         0012-F-013Y1.csv
#         0435-M-045Y1.csv
#         0100-M-051Y1.jpg
#         0342-F-060Y1.csv
#         0488-F-050Y1.csv
#         0493-F-029Y1.csv
#         0028-F-041Y1.jpg
#         0026-F-029Y1.jpg
#         0220-F-069Y1.jpg
#         0104-F-013Y1.csv
#         0402-F-042Y1.jpg
#         0079-F-012Y1.csv
#         0171-M-058Y1.jpg
#         0151-M-079Y1.csv
#         0155-F-067Y1.jpg
#         0303-M-044Y1.csv
#         0442-F-021Y1.jpg
#         0312-M-036Y1.csv
#         0381-F-062Y1.csv
#         0314-M-015Y1.jpg
#         0015-M-020Y1.csv
#         0036-F-016Y1.csv
#         0424-M-074Y1.jpg
#         0214-F-072Y1.jpg
#         0344-F-058Y1.jpg
#         0499-F-065Y1.csv
#         0394-F-062Y1.csv
#         0468-F-073Y1.jpg
#         0388-M-073Y1.csv
#         0051-F-066Y1.jpg
#         0243-M-068Y1.csv
#         0327-F-079Y1.jpg
#         0230-F-078Y1.jpg
#         0035-M-026Y1.csv
#         0066-F-019Y1.csv
#         0412-F-023Y1.jpg
#         0262-F-084Y1.jpg
#         0305-F-025Y1.csv
#         0138-M-064Y1.jpg
#         0388-M-073Y1.jpg
#         0444-F-020Y1.jpg
#         0108-F-036Y1.jpg
#         0420-F-079Y1.csv
#         0010-F-037Y1.csv
#         0441-M-044Y1.csv
#         0382-M-028Y1.jpg
#         0210-F-079Y1.jpg
#         0496-F-055Y1.jpg
#         0040-M-023Y1.csv
#         0136-F-027Y1.jpg
#         0434-M-041Y1.jpg
#         0225-M-086Y1.jpg
#         0143-F-089Y1.csv
#         0330-M-049Y1.csv
#         0277-F-050Y1.csv
#         0285-F-061Y1.jpg
#         0286-F-065Y1.jpg
#         0472-F-070Y1.csv
#         0064-F-017Y1.jpg
#         0261-F-056Y1.jpg
#         0240-F-061Y1.csv
#         0438-F-062Y1.csv
#         0038-F-020Y1.jpg
#         0238-F-067Y1.csv
#         0021-F-079Y1.csv
#         0272-M-035Y1.csv
#         0477-F-075Y1.csv
#         0379-M-040Y1.csv
#         0295-F-074Y1.csv
#         0318-F-053Y1.csv
#         0151-M-079Y1.jpg
#         0208-F-058Y1.jpg
#         0177-F-037Y1.csv
#         0013-M-022Y1.csv
#         0449-F-059Y1.jpg
#         0398-F-070Y1.jpg
#         0478-F-034Y1.jpg
#         0179-F-072Y1.csv
#         0167-F-049Y1.csv
#         0064-F-017Y1.csv
#         0475-M-053Y1.csv
#         0095-F-020Y1.jpg
#         0474-M-027Y1.jpg
#         0265-F-081Y1.jpg
#         0153-M-021Y1.jpg
#         0121-F-072Y1.jpg
#         0016-F-023Y1.csv
#         0148-M-058Y1.csv
#         0048-F-020Y1.jpg
#         0324-F-061Y1.jpg
#         0010-F-037Y1.jpg
#         0211-F-055Y1.jpg
#         0189-M-068Y1.csv
#         0489-F-052Y1.csv
#         0111-F-033Y1.jpg
#         0097-F-040Y1.jpg
#         0480-M-052Y1.jpg
#         0242-M-066Y1.jpg
#         0149-M-062Y1.jpg
#         0158-F-072Y1.jpg
#         0316-F-074Y1.csv
#         0023-F-014Y1.csv
#         0406-F-067Y1.csv
#         0238-F-067Y1.jpg
#         0047-F-023Y1.jpg
#         0113-F-082Y1.csv
#         0423-M-065Y1.csv
#         0428-F-077Y1.csv
#         0022-M-006Y1.csv
#         0322-F-061Y1.jpg
#         0417-F-069Y1.jpg
#         0406-F-067Y1.jpg
#         0191-F-066Y1.csv
#         0183-F-080Y1.csv
#         0156-M-050Y1.jpg
#         0246-M-027Y1.csv
#         0112-F-064Y1.jpg
#         0321-F-069Y1.jpg
#         0171-M-058Y1.csv
#         0293-M-068Y1.jpg
#         0219-F-077Y1.csv
#         0107-F-033Y1.jpg
#         0138-M-064Y1.csv
#         0169-F-044Y1.csv
#         0274-M-064Y1.jpg
#         0382-M-028Y1.csv
#         0412-F-023Y1.csv
#         0405-F-060Y1.csv
#         0492-F-051Y1.csv
#         0111-F-033Y1.csv
#         0054-F-079Y1.csv
#         0164-F-064Y1.jpg
#         0113-F-082Y1.jpg
#         0443-M-020Y1.csv
#         0034-F-067Y1.jpg
#         0250-F-069Y1.jpg
#         0402-F-042Y1.csv
#         0182-F-059Y1.csv
#         0114-F-038Y1.jpg
#         0228-F-057Y1.csv
#         0481-F-051Y1.csv
#         0014-F-062Y1.jpg
#         0302-F-068Y1.jpg
#         0258-F-058Y1.csv
#         0458-M-020Y1.csv
#         0278-F-055Y1.jpg
#         0203-M-081Y1.jpg
#         0235-F-073Y1.csv
#         0459-F-042Y1.csv
#         0134-M-038Y1.jpg
#         0494-F-066Y1.jpg
#         0470-F-065Y1.jpg
#         0330-M-049Y1.jpg
#         0312-M-036Y1.jpg
#         0264-F-044Y1.csv
#         0290-F-030Y1.jpg
#         0328-M-083Y1.jpg
#         0337-M-027Y1.jpg
#         0384-F-078Y1.jpg
#         0323-M-054Y1.csv
#         0068-F-017Y1.jpg
#         0315-F-067Y1.csv
#         0377-F-045Y1.csv
#         0275-M-074Y1.jpg
#         0398-F-070Y1.csv
#         0393-M-064Y1.jpg
#         0484-F-057Y1.jpg
#         0041-F-019Y1.jpg
#         0206-F-070Y1.jpg
#         0044-F-022Y1.jpg
#         0100-M-051Y1.csv
#         0186-F-042Y1.jpg
#         0478-F-034Y1.csv
#         0244-M-025Y1.jpg
#         0097-F-040Y1.csv
#         0443-M-020Y1.jpg
#         0204-F-084Y1.jpg
#         0390-M-080Y1.csv
#         0228-F-057Y1.jpg
#         0235-F-073Y1.jpg
#         0206-F-070Y1.csv
#         0098-F-065Y1.csv
#         0387-M-046Y1.jpg
#         0204-F-084Y1.csv
#         0218-M-067Y1.csv
#         0004-F-010Y1.jpg
#         0488-F-050Y1.jpg
#         0078-F-016Y1.jpg
#         0459-F-042Y1.jpg
#         0411-F-066Y1.jpg
#         0433-F-021Y1.jpg
#         0239-F-073Y1.csv
#         0284-F-061Y1.jpg
#         0291-M-073Y1.csv
#         0109-F-042Y1.jpg
#         0259-F-073Y1.jpg
#         0439-M-044Y1.csv
#         0322-F-061Y1.csv
#         0338-F-027Y1.jpg
#         0003-F-013Y1.jpg
#         0313-M-036Y1.jpg
#         0482-F-065Y1.jpg
#         0464-F-074Y1.csv
#         0211-F-055Y1.csv
#         0177-F-037Y1.jpg
#         0212-F-049Y1.jpg
#         0114-F-038Y1.csv
#         0095-F-020Y1.csv
#         0311-F-074Y1.csv
#         0421-F-083Y1.jpg
#         0159-M-062Y1.jpg
#         0140-M-024Y1.csv
#         0445-F-021Y1.csv
#         0254-F-064Y1.jpg
#         0200-M-065Y1.jpg
#         0102-F-013Y1.csv
#         0394-F-062Y1.jpg
#         0007-F-006Y1.csv
#         0467-F-025Y1.csv
#         0209-M-072Y1.jpg
#         0451-F-066Y1.jpg
#         0389-F-063Y1.jpg
#         0035-M-026Y1.jpg
#         0379-M-040Y1.jpg
#         0332-M-084Y1.csv
#         0454-F-040Y1.csv
#         0316-F-074Y1.jpg
#         0300-M-083Y1.jpg
#         0445-F-021Y1.jpg
#         0020-M-030Y1.jpg
#         0180-M-082Y1.jpg
#         0201-F-077Y1.csv
#         0226-M-060Y1.csv
#         0468-F-073Y1.csv
#         0390-M-080Y1.jpg
#         0476-M-047Y1.csv
#         0059-F-028Y1.jpg
#         0391-M-046Y1.csv
#         0149-M-062Y1.csv
#         0247-F-063Y1.csv
#         0420-F-079Y1.jpg
#         0207-F-061Y1.jpg
#         0307-F-072Y1.csv
#         0029-M-019Y1.jpg
#         0062-F-041Y1.csv
#         0223-F-063Y1.jpg
#         0389-F-063Y1.csv
#         0024-F-014Y1.jpg
#         0222-F-051Y1.jpg
#         0043-F-039Y1.jpg
#         0430-M-060Y1.csv
#         0147-F-086Y1.jpg
#         0345-M-064Y1.jpg
#         0397-M-023Y1.jpg
#         0249-F-074Y1.csv
#         0450-F-072Y1.csv
#         0175-M-053Y1.jpg
#         0072-F-035Y1.jpg
#         0274-M-064Y1.csv
#         0165-M-078Y1.csv
#         0471-M-081Y1.csv
#         0205-M-063Y1.jpg
#         0426-F-063Y1.jpg
#         0241-F-078Y1.jpg
#         0041-F-019Y1.csv
#         0427-F-050Y1.csv
#         0337-M-027Y1.csv
#         0425-M-062Y1.jpg
#         0467-F-025Y1.jpg
#         0181-M-069Y1.csv
#         0184-M-034Y1.jpg
#         0399-M-023Y1.csv
#         0387-M-046Y1.csv
#         0341-F-038Y1.csv
#         0135-F-024Y1.csv
#         0401-M-049Y1.csv
#         0032-F-007Y1.csv
#         0145-F-047Y1.jpg
#         0454-F-040Y1.jpg
#         0477-F-075Y1.jpg
#         0201-F-077Y1.jpg
#         0221-F-066Y1.csv
#         0399-M-023Y1.jpg
#         0263-F-049Y1.csv
#         0081-M-022Y1.csv
#         0046-F-021Y1.jpg
#         0185-F-073Y1.csv
#         0173-F-079Y1.csv
#         0011-F-063Y1.jpg
#         0236-M-065Y1.jpg
#         0275-M-074Y1.csv
#         0325-M-039Y1.jpg
#         0200-M-065Y1.csv
#         0241-F-078Y1.csv
#         0319-F-040Y1.jpg
#         0052-F-026Y1.jpg
#         0427-F-050Y1.jpg
#         0077-F-018Y1.jpg
#         0304-M-068Y1.csv
#         0181-M-069Y1.jpg
#         0207-F-061Y1.csv
#         0227-M-055Y1.csv
#         0109-F-042Y1.csv
#         0333-F-070Y1.csv
#         0291-M-073Y1.jpg
#         0251-M-055Y1.jpg
#         0009-F-038Y1.csv
#         0452-M-042Y1.csv
#         0391-M-046Y1.jpg
#         0150-F-081Y1.jpg
#         0197-F-077Y1.jpg
#         0144-F-038Y1.csv
#         0380-M-060Y1.csv
#         0184-M-034Y1.csv
#         0055-F-032Y1.csv
#         0296-F-039Y1.csv
#         0426-F-063Y1.csv
#         0163-F-053Y1.csv
#         0310-F-072Y1.csv
#         0336-M-050Y1.jpg
#         0471-M-081Y1.jpg
#         0492-F-051Y1.jpg
#         0401-M-049Y1.jpg
#         0271-F-062Y1.csv
#         0012-F-013Y1.jpg
#         0164-F-064Y1.csv
#         0479-F-033Y1.jpg
#         0277-F-050Y1.jpg
#         0453-F-064Y1.jpg
#         0195-F-064Y1.csv
#         0105-F-009Y1.jpg
#         0497-M-027Y1.jpg
#         0464-F-074Y1.jpg
#         0431-F-066Y1.jpg
#         0156-M-050Y1.csv
#         0005-F-025Y1.csv
#         0018-F-020Y1.jpg
#         0269-M-062Y1.csv
#         0231-F-056Y1.csv
#         0338-F-027Y1.csv
#         0060-F-013Y1.csv
#         0014-F-062Y1.csv
#         0305-F-025Y1.jpg
#         0053-F-040Y1.csv
#         0279-M-043Y1.jpg
#         0067-F-028Y1.jpg
#         0256-M-056Y1.jpg
#         0174-M-063Y1.csv
#         0501-M-080Y1.jpg
#         0168-M-055Y1.csv
#         0065-F-032Y1.jpg
#         0253-F-055Y1.csv
#         0260-F-084Y1.csv
#         0400-F-024Y1.csv
#         0396-F-053Y1.jpg
#         0053-F-040Y1.jpg
#         0187-F-067Y1.jpg
#         0154-M-078Y1.jpg
#         0430-M-060Y1.jpg
#         0071-F-016Y1.jpg
#         0282-F-034Y1.csv
#         0227-M-055Y1.jpg
#         0069-M-039Y1.jpg
#         0153-M-021Y1.csv
#         0378-F-075Y1.csv
#         0170-M-074Y1.jpg
#         0310-F-072Y1.jpg
#         0493-F-029Y1.jpg
#         0281-M-052Y1.jpg
#         0225-M-086Y1.csv
#         0239-F-073Y1.jpg
#         0234-F-073Y1.jpg
#         0423-M-065Y1.jpg
#         0294-F-068Y1.csv
#         0050-F-015Y1.csv
#         0285-F-061Y1.csv
#         0327-F-079Y1.csv
#         0296-F-039Y1.jpg
#         0219-F-077Y1.jpg
#         0187-F-067Y1.csv
#         0245-F-086Y1.csv
#         0046-F-021Y1.csv
#         0240-F-061Y1.jpg
#         0457-F-055Y1.csv
#         0024-F-014Y1.csv
#         0020-M-030Y1.csv
#         0299-F-060Y1.jpg
#         0340-M-056Y1.jpg
#         0469-F-068Y1.jpg
#         0198-F-063Y1.csv
#         0108-F-036Y1.csv
#         0036-F-016Y1.jpg
#         0054-F-079Y1.jpg
#         0301-F-036Y1.jpg
#         0249-F-074Y1.jpg
#         0385-F-071Y1.csv
#         0320-M-069Y1.csv
#         0306-M-072Y1.csv
#         0209-M-072Y1.csv

# %%
import os
import shutil

# Define paths
data_folder = '/kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400'

# Define writable paths in /kaggle/working
working_folder = '/kaggle/working/BUU-LSPINE_400'
train_images_folder = os.path.join(working_folder, 'train', 'images')
val_images_folder = os.path.join(working_folder, 'val', 'images')
test_images_folder = os.path.join(working_folder, 'test', 'images')
ap_folder = os.path.join(working_folder, 'AP')
la_folder = os.path.join(working_folder, 'LA')

# Function to create directories if they don't exist
def create_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f'Created directory: {directory}')

# Create writable directories
create_dir(train_images_folder)
create_dir(val_images_folder)
create_dir(test_images_folder)
create_dir(ap_folder)
create_dir(la_folder)

# Function to copy images based on naming convention
def copy_images_by_naming_convention(folder_path, destination_ap, destination_la):
    # List images in folder
    images = [f for f in os.listdir(folder_path) if f.endswith('.jpg')]
    # Copy each image to appropriate destination folder
    for image in images:
        if image.endswith('0.jpg'):
            destination_folder = destination_ap
        elif image.endswith('1.jpg'):
            destination_folder = destination_la
        else:
            continue  # Skip if not AP or LA image

        src = os.path.join(folder_path, image)
        dst = os.path.join(destination_folder, image)
        shutil.copy(src, dst)
        print(f'Copied {image} to {destination_folder}')


# Copy train images
copy_images_by_naming_convention(train_images_folder, ap_folder, la_folder)

# Copy validation images
copy_images_by_naming_convention(val_images_folder, ap_folder, la_folder)

# Copy test images
copy_images_by_naming_convention(test_images_folder, ap_folder, la_folder)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import random

# Function to load and display an image with corresponding points from CSV
def display_random_image_with_points(image_dir, csv_dir, view):
    # List all image files in the directory
    image_files = os.listdir(image_dir)
    random_image_file = random.choice(image_files)

    # Construct paths
    image_path = os.path.join(image_dir, random_image_file)
    csv_path = os.path.join(csv_dir, random_image_file.replace('.jpg', '.csv').replace('.jpeg', '.csv').replace('.png', '.csv'))

    # Print debug information
    print(f"Image Path: {image_path}")
    print(f"CSV Path: {csv_path}")

    # Check file existence
    if not os.path.exists(image_path):
        print(f"Image file does not exist: {image_path}")
        return
    if not os.path.exists(csv_path):
        print(f"CSV file does not exist: {csv_path}")
        return

    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Unable to read image: {image_path}")
        return
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Read the CSV file
    points = pd.read_csv(csv_path, header=None)

    # Define labels for AP and LA views
    if 'AP' in view:
        labels = ['L1a, 1', 'L1a, 2', 'L1b, 1', 'L1b, 2',
                  'L2a, 1', 'L2a, 2', 'L2b, 1', 'L2b, 2',
                  'L3a, 1', 'L3a, 2', 'L3b, 1', 'L3b, 2',
                  'L4a, 1', 'L4a, 2', 'L4b, 1', 'L4b, 2',
                  'L5a, 1', 'L5a, 2', 'L5b, 1', 'L5b, 2']
    elif 'LA' in view:
        labels = ['L1a, 1', 'L1a, 2', 'L1b, 1', 'L1b, 2',
                  'L2a, 1', 'L2a, 2', 'L2b, 1', 'L2b, 2',
                  'L3a, 1', 'L3a, 2', 'L3b, 1', 'L3b, 2',
                  'L4a, 1', 'L4a, 2', 'L4b, 1', 'L4b, 2',
                  'L5a, 1', 'L5a, 2', 'L5b, 1', 'L5b, 2',
                  'S1a, 1', 'S1a, 2']

    # Plot the image
    plt.figure(figsize=(10, 10))
    plt.imshow(image)

    # Plot the points with annotations
    for index in range(0, len(points) - 1, 2):  # Iterate by pairs of edge lines
        # Check if enough rows remain to access the next pair of points
        if index + 1 < len(points):
            x1, y1, x2, y2, _ = points.iloc[index]  # First point
            x3, y3, x4, y4, _ = points.iloc[index + 1]  # Second point

            # Get unique labels for this pair
            label1 = labels[index // 2 * 4]
            label2 = labels[index // 2 * 4 + 1]
            label3 = labels[index // 2 * 4 + 2]
            label4 = labels[index // 2 * 4 + 3]

            # Plot points as small yellow circles
            plt.scatter([x1, x2], [y1, y2], color='yellow', s=15)

            # Display labels near the points
            plt.text(x1, y1, label1, color='yellow', fontsize=6, ha='right', va='top')
            plt.text(x2, y2, label2, color='yellow', fontsize=6, ha='left', va='top')

            # Connect the points with a line
            plt.plot([x1, x2], [y1, y2], color='green')

            # Plot points for the second pair
            plt.scatter([x3, x4], [y3, y4], color='yellow', s=15)

            # Display labels near the points for the second pair
            plt.text(x3, y3, label3, color='yellow', fontsize=6, ha='right', va='top')
            plt.text(x4, y4, label4, color='yellow', fontsize=6, ha='left', va='top')

            # Connect the points of the second pair with a line
            plt.plot([x3, x4], [y3, y4], color='green')

    # Add the first sacral vertebra edge line (points 21 and 22) for LA view
    if 'LA' in view and len(points) > 10:
        x1, y1, x2, y2, _ = points.iloc[10]  # S1a, 1 and S1a, 2

        # Get labels for sacral vertebra
        label1 = labels[20]
        label2 = labels[21]

        # Plot points as small yellow circles
        plt.scatter([x1, x2], [y1, y2], color='yellow', s=15)

        # Display labels near the points
        plt.text(x1, y1, label1, color='yellow', fontsize=6, ha='right', va='top')
        plt.text(x2, y2, label2, color='yellow', fontsize=6, ha='left', va='top')

        # Connect the points with a line
        plt.plot([x1, x2], [y1, y2], color='green')

    plt.title(f'Random {view} Image with Annotation Edge Lines')
    plt.axis('off')  # Hide axis for cleaner visualization
    plt.show()

# Example paths
ap_image_dir = '/kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/AP'  # Directory containing AP view images
ap_csv_dir = '/kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/AP'  # Directory containing corresponding CSV files

la_image_dir = '/kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/LA'  # Directory containing LA view images
la_csv_dir = '/kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/LA'  # Directory containing corresponding CSV files

# Display random image with points for AP and LA views
display_random_image_with_points(ap_image_dir, ap_csv_dir, 'AP')
display_random_image_with_points(la_image_dir, la_csv_dir, 'LA')
# Out:
# Image Path: /kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/AP/0436-F-054Y0.csv
# CSV Path: /kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/AP/0436-F-054Y0.csv
# Unable to read image: /kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/AP/0436-F-054Y0.csv
# Image Path: /kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/LA/0201-F-077Y1.csv
# CSV Path: /kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/LA/0201-F-077Y1.csv
# Unable to read image: /kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/LA/0201-F-077Y1.csv

# %%
filename = "0020-M-030Y1.jpg"

# Split filename by hyphen to extract parts
parts = filename.split('-')

# Extract Patient_ID (parts[0])
patient_id = parts[0]

# Extract Gender (parts[1])
gender = parts[1]

# Extract Age (parts[2][:3] to get the first three characters)
age = parts[2][:3]  # Extracts "037"

# Extract View_Type (last character of parts[2])
view_type = 'AP' if parts[2][-1] == '0' else 'LA'

print(f"Patient_ID: {patient_id}")
print(f"Gender: {gender}")
print(f"Age: {age}")
print(f"View_Type: {view_type}")
# Out:
# Patient_ID: 0020
# Gender: M
# Age: 030
# View_Type: LA

# %%
from sklearn.model_selection import train_test_split

import pandas as pd
import os
import shutil

# Function to update paths in metadata CSV
def update_metadata_paths(metadata_csv_path, data_folder):
    df = pd.read_csv(metadata_csv_path)

    updated_image_paths = []
    updated_csv_paths = []

    for index, row in df.iterrows():
        image_path = row['Image_Path']
        csv_path = row['CSV_Path']

        # Extract image name
        image_name = os.path.basename(image_path)
        csv_name = os.path.basename(csv_path)
        
        # Update paths
        updated_image_path = os.path.join(data_folder, row['View_Type'], image_name)
        updated_csv_path = os.path.join(data_folder, row['View_Type'], csv_name)

        updated_image_paths.append(updated_image_path)
        updated_csv_paths.append(updated_csv_path)

    df['Image_Path'] = updated_image_paths
    df['CSV_Path'] = updated_csv_paths

    # Save updated metadata CSV
    updated_metadata_path = os.path.join('/kaggle/working', os.path.basename(metadata_csv_path))
    df.to_csv(updated_metadata_path, index=False)
    print(f"Updated metadata saved to: {updated_metadata_path}")

# Define paths
data_folder = '/kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400'
metadata_csv_path = '/kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/metadata.csv'
working_metadata_path = '/kaggle/working/metadata.csv'

# Copy metadata CSV to working directory
shutil.copy(metadata_csv_path, working_metadata_path)

# Update paths in metadata CSV
update_metadata_paths(working_metadata_path, data_folder)



# Split the dataset into train, validation, and test sets (80%, 10%, 10%)
train_df, val_test_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(val_test_df, test_size=0.5, random_state=42)

# Save train, validation, and test CSVs
train_df.to_csv(train_csv_path, index=False)
val_df.to_csv(val_csv_path, index=False)
test_df.to_csv(test_csv_path, index=False)

print(f"Train metadata saved to: {train_csv_path}")
print(f"Validation metadata saved to: {val_csv_path}")
print(f"Test metadata saved to: {test_csv_path}")
# Out:
# Updated metadata saved to: /kaggle/working/metadata.csv
# Train metadata saved to: /kaggle/working/train_metadata.csv
# Validation metadata saved to: /kaggle/working/val_metadata.csv
# Test metadata saved to: /kaggle/working/test_metadata.csv

# %%
# !pip install tensorflow pandas opencv-python
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (2.15.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (4.10.0.82)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow) (3.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import pandas as pd
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split

# Update paths to reflect the correct directory structure in Kaggle
train_metadata_path = '/kaggle/working/train_metadata.csv'
val_metadata_path = '/kaggle/working/val_metadata.csv'
test_metadata_path = '/kaggle/working/test_metadata.csv'
working_metadata_path = '/kaggle/working/metadata.csv'


# Function to load image and keypoints
def load_image_and_keypoints(image_path, csv_path, image_size=(640, 640)):
    # Check if image path exists
    if not tf.io.gfile.exists(image_path):
        raise FileNotFoundError(f"Image file not found: {image_path}")

    # Read image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, image_size)

    # Read keypoints
    keypoints = pd.read_csv(csv_path, header=None).values[:, :4].flatten()

    return image, keypoints

# Function to create dataset from metadata
def create_dataset(working_metadata_path, image_size=(640, 640), view='AP'):
    metadata = pd.read_csv(working_metadata_path)
    images = []
    keypoints = []

    for index, row in metadata.iterrows():
        if row['View_Type'] == view:
            image_path = row['Image_Path']
            csv_path = row['CSV_Path']
            try:
                image, kp = load_image_and_keypoints(image_path, csv_path, image_size=image_size)
                images.append(image)
                keypoints.append(kp)
            except Exception as e:
                print(f"Error loading {image_path}: {e}")

    images = np.array(images, dtype='float32') / 255.0
    keypoints = np.array(keypoints, dtype='float32')

    return images, keypoints

# Create datasets for AP and LA views separately
train_images_ap, train_keypoints_ap = create_dataset(train_metadata_path, view='AP')
train_images_la, train_keypoints_la = create_dataset(train_metadata_path, view='LA')

val_images_ap, val_keypoints_ap = create_dataset(val_metadata_path, view='AP')
val_images_la, val_keypoints_la = create_dataset(val_metadata_path, view='LA')

test_images_ap, test_keypoints_ap = create_dataset(test_metadata_path, view='AP')
test_images_la, test_keypoints_la = create_dataset(test_metadata_path, view='LA')
# Out:
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0314-M-015Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0314-M-015Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0431-F-066Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0431-F-066Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0441-M-044Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0441-M-044Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0491-F-018Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0491-F-018Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0102-F-013Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0102-F-013Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0199-F-035Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0199-F-035Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0438-F-062Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0438-F-062Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0487-F-047Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0487-F-047Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0422-F-088Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0422-F-088Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0163-F-053Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0163-F-053Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0482-F-065Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0482-F-065Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0261-F-056Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0261-F-056Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0068-F-017Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0068-F-017Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0250-F-069Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0250-F-069Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0070-F-027Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0070-F-027Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0295-F-074Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0295-F-074Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0134-M-038Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0134-M-038Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0222-F-051Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0222-F-051Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0384-F-078Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0384-F-078Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0208-F-058Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0208-F-058Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0077-F-018Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0077-F-018Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0170-M-074Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0170-M-074Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0036-F-016Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0036-F-016Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0105-F-009Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0105-F-009Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0452-M-042Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0452-M-042Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0179-F-072Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0179-F-072Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0079-F-012Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0079-F-012Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0213-F-086Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0213-F-086Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0206-F-070Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0206-F-070Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0025-F-015Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0025-F-015Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0245-F-086Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0245-F-086Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0298-M-011Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0298-M-011Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0189-M-068Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0189-M-068Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0420-F-079Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0420-F-079Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0183-F-080Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0183-F-080Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0016-F-023Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0016-F-023Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0072-F-035Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0072-F-035Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0398-F-070Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0398-F-070Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0200-M-065Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0200-M-065Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0343-M-031Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0343-M-031Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0307-F-072Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0307-F-072Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0290-F-030Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0290-F-030Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0475-M-053Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0475-M-053Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0177-F-037Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0177-F-037Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0484-F-057Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0484-F-057Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0050-F-015Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0050-F-015Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0145-F-047Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0145-F-047Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0444-F-020Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0444-F-020Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0069-M-039Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0069-M-039Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0325-M-039Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0325-M-039Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0281-M-052Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0281-M-052Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0274-M-064Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0274-M-064Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0434-M-041Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0434-M-041Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0019-F-015Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0019-F-015Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0447-M-067Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0447-M-067Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0464-F-074Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0464-F-074Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0066-F-019Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0066-F-019Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0425-M-062Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0425-M-062Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0429-M-083Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0429-M-083Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0379-M-040Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0379-M-040Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0035-M-026Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0035-M-026Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0104-F-013Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0104-F-013Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0056-F-069Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0056-F-069Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0344-F-058Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0344-F-058Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0231-F-056Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0231-F-056Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0288-M-077Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0288-M-077Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0418-F-025Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0418-F-025Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0428-F-077Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0428-F-077Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0230-F-078Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0230-F-078Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0459-F-042Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0459-F-042Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0201-F-077Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0201-F-077Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0299-F-060Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0299-F-060Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0090-F-016Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0090-F-016Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0150-F-081Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0150-F-081Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0147-F-086Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0147-F-086Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0393-M-064Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0393-M-064Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0121-F-072Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0121-F-072Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0143-F-089Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0143-F-089Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0018-F-020Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0018-F-020Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0047-F-023Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0047-F-023Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0046-F-021Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0046-F-021Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0214-F-072Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0214-F-072Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0223-F-063Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0223-F-063Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0227-M-055Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0227-M-055Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0311-F-074Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0311-F-074Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0010-F-037Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0010-F-037Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0014-F-062Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0014-F-062Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0427-F-050Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0427-F-050Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0312-M-036Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0312-M-036Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0426-F-063Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0426-F-063Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0435-M-045Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0435-M-045Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0001-F-037Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0001-F-037Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0305-F-025Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0305-F-025Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0033-F-023Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0033-F-023Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0279-M-043Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0279-M-043Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0442-F-021Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0442-F-021Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0260-F-084Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0260-F-084Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0294-F-068Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0294-F-068Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0118-F-015Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0118-F-015Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0470-F-065Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0470-F-065Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0363-F-062Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0363-F-062Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0219-F-077Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0219-F-077Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0490-F-038Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0490-F-038Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0204-F-084Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0204-F-084Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0073-F-036Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0073-F-036Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0334-F-058Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0334-F-058Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0107-F-033Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0107-F-033Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0240-F-061Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0240-F-061Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0327-F-079Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0327-F-079Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0296-F-039Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0296-F-039Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0140-M-024Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0140-M-024Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0146-M-057Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0146-M-057Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0166-F-071Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0166-F-071Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0377-F-045Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0377-F-045Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0293-M-068Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0293-M-068Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0017-F-040Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0017-F-040Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0381-F-062Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0381-F-062Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0159-M-062Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0159-M-062Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0287-M-078Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0287-M-078Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0333-F-070Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0333-F-070Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0421-F-083Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0421-F-083Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0197-F-077Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0197-F-077Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0471-M-081Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0471-M-081Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0335-F-079Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0335-F-079Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0396-F-053Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0396-F-053Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0417-F-069Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0417-F-069Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0043-F-039Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0043-F-039Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0450-F-072Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0450-F-072Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0462-M-041Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0462-M-041Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0308-M-067Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0308-M-067Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0246-M-027Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0246-M-027Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0152-F-026Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0152-F-026Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0054-F-079Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0054-F-079Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0139-F-077Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0139-F-077Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0234-F-073Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0234-F-073Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0394-F-062Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0394-F-062Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0188-F-066Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0188-F-066Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0169-F-044Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0169-F-044Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0239-F-073Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0239-F-073Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0058-F-008Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0058-F-008Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0412-F-023Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0412-F-023Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0445-F-021Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0445-F-021Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0186-F-042Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0186-F-042Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0472-F-070Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0472-F-070Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0187-F-067Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0187-F-067Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0493-F-029Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0493-F-029Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0316-F-074Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0316-F-074Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0415-F-061Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0415-F-061Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0034-F-067Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0034-F-067Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0238-F-067Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0238-F-067Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0416-F-022Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0416-F-022Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0496-F-055Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0496-F-055Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0013-M-022Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0013-M-022Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0397-M-023Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0397-M-023Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0453-F-064Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0453-F-064Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0020-M-030Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0020-M-030Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0228-F-057Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0228-F-057Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0044-F-022Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0044-F-022Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0229-F-078Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0229-F-078Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0300-M-083Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0300-M-083Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0388-M-073Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0388-M-073Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0330-M-049Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0330-M-049Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0210-F-079Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0210-F-079Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0174-M-063Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0174-M-063Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0446-M-060Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0446-M-060Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0382-M-028Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0382-M-028Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0148-M-058Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0148-M-058Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0220-F-069Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0220-F-069Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0458-M-020Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0458-M-020Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0061-F-021Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0061-F-021Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0282-F-034Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0282-F-034Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0342-F-060Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0342-F-060Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0029-M-019Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0029-M-019Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0165-M-078Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0165-M-078Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0405-F-060Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0405-F-060Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0315-F-067Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0315-F-067Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0253-F-055Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0253-F-055Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0157-M-060Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0157-M-060Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0113-F-082Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0113-F-082Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0225-M-086Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0225-M-086Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0387-M-046Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0387-M-046Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0005-F-025Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0005-F-025Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0041-F-019Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0041-F-019Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0202-F-068Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0202-F-068Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0233-F-064Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0233-F-064Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0015-M-020Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0015-M-020Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0071-F-016Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0071-F-016Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0340-M-056Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0340-M-056Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0286-F-065Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0286-F-065Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0032-F-007Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0032-F-007Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0467-F-025Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0467-F-025Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0280-F-051Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0280-F-051Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0049-F-013Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0049-F-013Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0480-M-052Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0480-M-052Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0241-F-078Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0241-F-078Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0207-F-061Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0207-F-061Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0181-M-069Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0181-M-069Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0151-M-079Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0151-M-079Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0277-F-050Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0277-F-050Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0153-M-021Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0153-M-021Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0168-M-055Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0168-M-055Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0065-F-032Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0065-F-032Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0191-F-066Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0191-F-066Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0264-F-044Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0264-F-044Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0009-F-038Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0009-F-038Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0048-F-020Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0048-F-020Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0322-F-061Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0322-F-061Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0402-F-042Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0402-F-042Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0318-F-053Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0318-F-053Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0390-M-080Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0390-M-080Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0198-F-063Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0198-F-063Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0196-F-051Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0196-F-051Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0185-F-073Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0185-F-073Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0451-F-066Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0451-F-066Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0436-F-054Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0436-F-054Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0252-M-056Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0252-M-056Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0172-F-078Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0172-F-078Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0182-F-059Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0182-F-059Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0243-M-068Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0243-M-068Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0385-F-071Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0385-F-071Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0386-M-071Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0386-M-071Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0171-M-058Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0171-M-058Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0221-F-066Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0221-F-066Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0267-F-065Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0267-F-065Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0292-F-058Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0292-F-058Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0180-M-082Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0180-M-082Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0284-F-061Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0284-F-061Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0486-M-033Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0486-M-033Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0326-F-026Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0326-F-026Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0156-M-050Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0156-M-050Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0291-M-073Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0291-M-073Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0488-F-050Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0488-F-050Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0283-M-030Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0283-M-030Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0403-M-039Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0403-M-039Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0466-F-046Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0466-F-046Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0313-M-036Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0313-M-036Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0341-F-038Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0341-F-038Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0478-F-034Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0478-F-034Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0476-M-047Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0476-M-047Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0285-F-061Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0285-F-061Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0449-F-059Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0449-F-059Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0126-F-026Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0126-F-026Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0297-F-031Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0297-F-031Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0211-F-055Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0211-F-055Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0053-F-040Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0053-F-040Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0226-M-060Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0226-M-060Y0.jpg
# ...
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0326-F-026Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0326-F-026Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0318-F-053Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0318-F-053Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0259-F-073Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0259-F-073Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0268-M-052Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0268-M-052Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0465-F-040Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0465-F-040Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0149-M-062Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0149-M-062Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0218-M-067Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0218-M-067Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0497-M-027Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0497-M-027Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0057-F-030Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0057-F-030Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0463-F-020Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0463-F-020Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0263-F-049Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0263-F-049Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0332-M-084Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0332-M-084Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0437-F-065Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0437-F-065Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0062-F-041Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0062-F-041Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0306-M-072Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0306-M-072Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0254-F-064Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0254-F-064Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0098-F-065Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0098-F-065Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0003-F-013Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0003-F-013Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0400-F-024Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0400-F-024Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0081-M-022Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0081-M-022Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0158-F-072Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0158-F-072Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0055-F-032Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0055-F-032Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0235-F-073Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0235-F-073Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0142-F-051Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0142-F-051Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0319-F-040Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0319-F-040Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0101-F-022Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0101-F-022Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0108-F-036Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0108-F-036Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0194-F-077Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0194-F-077Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0276-F-076Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0276-F-076Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0378-F-075Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0378-F-075Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0455-F-078Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0455-F-078Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0460-F-019Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0460-F-019Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0323-M-054Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0323-M-054Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0100-M-051Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0100-M-051Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0022-M-006Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0022-M-006Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0097-F-040Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0097-F-040Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0468-F-073Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0468-F-073Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0067-F-028Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0067-F-028Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0469-F-068Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0469-F-068Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0303-M-044Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0303-M-044Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0278-F-055Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0278-F-055Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0184-M-034Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0184-M-034Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0141-M-055Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0141-M-055Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0021-F-079Y0.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP/0021-F-079Y0.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0175-M-053Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0175-M-053Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0286-F-065Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0286-F-065Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0221-F-066Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0221-F-066Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0046-F-021Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0046-F-021Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0112-F-064Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0112-F-064Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0166-F-071Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0166-F-071Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0157-M-060Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0157-M-060Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0268-M-052Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0268-M-052Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0302-F-068Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0302-F-068Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0059-F-028Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0059-F-028Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0450-F-072Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0450-F-072Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0058-F-008Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0058-F-008Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0468-F-073Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0468-F-073Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0240-F-061Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0240-F-061Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0109-F-042Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0109-F-042Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0406-F-067Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0406-F-067Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0172-F-078Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0172-F-078Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0300-M-083Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0300-M-083Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0301-F-036Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0301-F-036Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0400-F-024Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0400-F-024Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0384-F-078Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0384-F-078Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0285-F-061Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0285-F-061Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0490-F-038Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0490-F-038Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0418-F-025Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0418-F-025Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0022-M-006Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0022-M-006Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0479-F-033Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0479-F-033Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0298-M-011Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0298-M-011Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0019-F-015Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0019-F-015Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0252-M-056Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0252-M-056Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0148-M-058Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0148-M-058Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0231-F-056Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0231-F-056Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0260-F-084Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0260-F-084Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0390-M-080Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0390-M-080Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0163-F-053Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0163-F-053Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0244-M-025Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0244-M-025Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0478-F-034Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0478-F-034Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0458-M-020Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0458-M-020Y1.jpg
# Error loading /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0420-F-079Y1.jpg: Image file not found: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA/0420-F-079Y1.jpg

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model

# Define and compile ResNet50 model for AP view
def create_resnet_model():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(640, 640, 3))
    x = base_model.output
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    predictions = Dense(40 if view == 'AP' else 44)(x)  # Adjust output size for AP and LA views
    model = Model(inputs=base_model.input, outputs=predictions)

    for layer in base_model.layers:
        layer.trainable = False

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])  # Adjust loss and metrics as needed

    return model

# Create ResNet50 models for AP and LA views
resnet_ap = create_resnet_model(view='AP')
resnet_la = create_resnet_model(view='LA')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping



# Define callbacks for training
checkpoint_ap = ModelCheckpoint('/kaggle/working/resnet_ap.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
checkpoint_la = ModelCheckpoint('/kaggle/working/resnet_la.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
reduce_lr_ap = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)
reduce_lr_la = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

# Train ResNet50 models
history_ap = resnet_ap.fit(train_images_ap, train_keypoints_ap, epochs=20, batch_size=4,
                           validation_data=(val_images_ap, val_keypoints_ap),
                           callbacks=[checkpoint_ap, reduce_lr_ap])

history_la = resnet_la.fit(train_images_la, train_keypoints_la, epochs=20, batch_size=4,
                           validation_data=(val_images_la, val_keypoints_la),
                           callbacks=[checkpoint_la, reduce_lr_la])

# Evaluate models on test set
ap_loss, ap_accuracy = resnet_ap.evaluate(test_images_ap, test_keypoints_ap)
la_loss, la_accuracy = resnet_la.evaluate(test_images_la, test_keypoints_la)

print(f"AP Model Accuracy: {ap_accuracy}")
print(f"LA Model Accuracy: {la_accuracy}")

# Define callbacks
callbacks = [
    ModelCheckpoint(filepath='best_model.h5', save_best_only=True, monitor='val_loss', mode='min'),
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
]

# Create and train ResNet50 model for AP view
ap_model = create_resnet_model(input_shape=(640, 640, 3))
ap_model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
ap_history = ap_model.fit(ap_train_generator, epochs=20, validation_data=ap_val_generator, callbacks=callbacks)

# Create and train ResNet50 model for LA view
la_model = create_resnet_model(input_shape=(640, 640, 3))
la_model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
la_history = la_model.fit(la_train_generator, epochs=20, validation_data=la_val_generator, callbacks=callbacks)

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


# Define callbacks
callbacks = [
    ModelCheckpoint(filepath='/kaggle/input/spine-x-rays-vertebrae-detection/BUU-LSPINE_400/best_model.h5', save_best_only=True, monitor='val_loss', mode='min'),
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
]

# %% [markdown]
# Functions to create MobileNetV2 model

# %%
#for AP
def create_mobilenetv2_model_AP(input_shape):
    base_model = MobileNetV2(include_top=False, weights='imagenet', input_shape=input_shape)
    x = Flatten()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dense(40, activation='linear')(x)  # Adjust output shape according to your needs
    model = Model(inputs=base_model.input, outputs=x)
    return model

# %%
# Create and train MobileNetV2 model for LA view
la_model = create_mobilenetv2_model_LA(input_shape=(640, 640, 3))
la_model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
la_history = la_model.fit(la_train_generator, epochs=20, validation_data=la_val_generator, callbacks=callbacks)

# %%
# !pip install ultralytics

# %%
import pandas as pd
import os

# Defining the class mapping
class_map = {
    'AP': {
        'APL1': 1, 'APL2': 2, 'APL3': 3, 'APL4': 4, 'APL5': 5
    },
    'LA': {
        'LAL1': 1, 'LAL2': 2, 'LAL3': 3, 'LAL4': 4, 'LAL5': 5,
        'S1a': 11
    }
}

# Function to convert coordinates to YOLO format
def convert_to_yolo_format(image_width, image_height, x1, y1, x2, y2):
    x_center = (x1 + x2) / 2.0 / image_width
    y_center = (y1 + y2) / 2.0 / image_height
    width = abs(x2 - x1) / image_width
    height = abs(y2 - y1) / image_height
    return x_center, y_center, width, height

# Function to generate class_id based on edge line and view
def get_class_id(edge_line, view):
    return class_map[view].get(edge_line, -1)  # Return -1 if not found

# Function to generate YOLO annotations from CSV
def generate_yolo_annotations(image_dir, csv_dir, output_dir, view):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for image_file in os.listdir(image_dir):
        if image_file.lower().endswith('.jpg') or image_file.lower().endswith('.jpeg') or image_file.lower().endswith('.png'):
            image_path = os.path.join(image_dir, image_file)
            csv_path = os.path.join(csv_dir, image_file.replace('.jpg', '.csv').replace('.jpeg', '.csv').replace('.png', '.csv'))

            if os.path.exists(csv_path):
                # Read the image to get its dimensions
                image = cv2.imread(image_path)
                image_height, image_width, _ = image.shape

                # Read the CSV file
                points = pd.read_csv(csv_path, header=None)

                # Prepare the output annotation file
                annotation_file = os.path.join(output_dir, image_file.replace('.jpg', '.txt').replace('.jpeg', '.txt').replace('.png', '.txt'))

                with open(annotation_file, 'w') as f:
                    for index, row in points.iterrows():
                        x1, y1, x2, y2, _ = row  # Assuming CSV columns are x1, y1, x2, y2, class_id
                        class_id = get_class_id(f'L{index + 1}a', view)  # Assuming rows are labeled L1a, L2a, ..., S1a for LA view
                        if class_id != -1:  # Only write valid classes
                            x_center, y_center, width, height = convert_to_yolo_format(image_width, image_height, x1, y1, x2, y2)
                            f.write(f"{class_id} {x_center} {y_center} {width} {height}\n")

# Example paths
ap_image_dir = '/content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP'  # Directory containing AP view images
ap_csv_dir = '/content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP'  # Directory containing corresponding CSV files
ap_output_dir = '/content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/AP_YOLO_annotations'  # Output directory for YOLO annotations

la_image_dir = '/content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA'  # Directory containing LA view images
la_csv_dir = '/content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA'  # Directory containing corresponding CSV files
la_output_dir = '/content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400/LA_YOLO_annotations'  # Output directory for YOLO annotations

# Generate YOLO annotations for AP and LA views
generate_yolo_annotations(ap_image_dir, ap_csv_dir, ap_output_dir, 'AP')
generate_yolo_annotations(la_image_dir, la_csv_dir, la_output_dir, 'LA')

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Define paths
data_folder = '/content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400'
ap_folder = os.path.join(data_folder, 'AP')
la_folder = os.path.join(data_folder, 'LA')

# Function to gather images
def gather_images(data_folder):
    ap_images = [os.path.join(ap_folder, f) for f in os.listdir(ap_folder) if f.lower().endswith('.jpg')]
    la_images = [os.path.join(la_folder, f) for f in os.listdir(la_folder) if f.lower().endswith('.jpg')]
    return ap_images, la_images

# Function to split dataset
def split_dataset(images, val_ratio=0.1, test_ratio=0.1):
    train_images, temp_images = train_test_split(images, test_size=(val_ratio + test_ratio), random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=test_ratio / (val_ratio + test_ratio), random_state=42)
    return train_images, val_images, test_images

# Function to move files to respective folders
def move_files(file_list, dest_folder):
    os.makedirs(dest_folder, exist_ok=True)
    for file_name in file_list:
        shutil.move(file_name, dest_folder)
        print(f"Moved {file_name} to {dest_folder}")

# Gather AP and LA images
ap_images, la_images = gather_images(data_folder)

# Split AP and LA images into train, val, test
train_ap_images, val_ap_images, test_ap_images = split_dataset(ap_images)
train_la_images, val_la_images, test_la_images = split_dataset(la_images)

# Define folders
train_folder = os.path.join(data_folder, 'train', 'images')
val_folder = os.path.join(data_folder, 'val', 'images')
test_folder = os.path.join(data_folder, 'test', 'images')

# Move images to respective train, val, test folders
move_files(train_ap_images, train_folder)
move_files(val_ap_images, val_folder)
move_files(test_ap_images, test_folder)

move_files(train_la_images, train_folder)
move_files(val_la_images, val_folder)
move_files(test_la_images, test_folder)

# Display number of images in each set
print(f"Train AP images: {len(train_ap_images)}, Train LA images: {len(train_la_images)}")
print(f"Val AP images: {len(val_ap_images)}, Val LA images: {len(val_la_images)}")
print(f"Test AP images: {len(test_ap_images)}, Test LA images: {len(test_la_images)}")

# %%
config_content = """
path: /content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400
train: train/images
val: val/images
test: test/images

nc: 1
names: ['vertebra']
"""

config_path = os.path.join(data_folder, 'yolov8_config.yaml')
with open(config_path, 'w') as f:
    f.write(config_content)

# %%
from ultralytics import YOLO

# Define the path to your configuration file
data_folder = '/content/drive/My Drive/INTERNSHIP PROJECTS/BUU-LSPINE_400'
config_path = os.path.join(data_folder, 'yolov8_config.yaml')

# Loading YOLO model
model = YOLO('yolov8x.pt')

# Training the model with early stopping
model.train(data=config_path, epochs=100, imgsz=640, batch=16, patience=10)
